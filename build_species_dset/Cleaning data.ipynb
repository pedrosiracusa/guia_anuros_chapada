# %%
import pandas as pd
import numpy as np
import re
import json

# %%
pd.set_option('display.max_columns',50)

# %%
dataFile = './speciesdata.csv'

# %%
excludedCols = ['Responsável','Guia','Folder','Artigo','Família.1', 
                'Glossário','Fotos adultos','Fotos girinos',
                'Vídeos','Áudios', 'Diagnose','DOI' ]

df = pd.read_csv(dataFile, usecols=lambda x: x not in excludedCols)

# %%
# Drop every row after the one containing only null values
nullrow = df[df.apply(lambda x: all(x.isnull()), axis=1)].index[0]
df.drop(axis=1, index=range( nullrow,df.shape[0] ), inplace=True)

# %%
df.drop('Red List.1', axis=1, inplace=True)

# %%
df.rename( {'Espécie': 'speciesName', 
            'Família': 'family',
            'Postura dos ovos (habitat breeding)*': 'habitat_breeding',
            'Chances de encontros (muito raro/raro/frequente/muito frequente)': 'detectability',
            'Nome Comum': 'vernacularNames'}, axis=1, inplace=True)

# %%
df.replace('^-$', '', inplace=True, regex=True)

# %%
df
# Out:
#              family                                        speciesName  \
# 0      AROMOBATIDAE                Allobates goianus (Bokermann, 1975)
# 1         BUFONIDAE                  Rhaebo guttatus (Schneider, 1799)
# 2         BUFONIDAE          Rhinella mirandaribeiroi (Gallardo, 1965)
# 3         BUFONIDAE                  Rhinella ocellata (Günther, 1858)
# 4         BUFONIDAE                   Rhinella rubescens (Lutz, 1925)*
# 5         BUFONIDAE                Rhinella schneideri (Werner, 1894)*
# 6    CRAUGASTORIDAE      Barycholos ternetzi (Miranda- Ribeiro, 1937)*
# 7     DENDROBATIDAE                  Ameerega flavopicta (Lutz, 1925)*
# 8           HYLIDAE  Aplastodiscus lutzorum (Berneck, Giaretta, Bra...
# 9           HYLIDAE  Bokermannohyla pseudopseudis (Miranda-Ribeiro,...
# 10          HYLIDAE      Dendropsophus jimi (Napoli & Caramashi, 1999)
# 11          HYLIDAE              Dendropsophus minutus (Peters, 1872)*
# 12          HYLIDAE  Dendropsophus rubicundulus (Reinhardt & Lutken...
# 13          HYLIDAE                   Boana albopunctata Dubois, 2017*
# 14          HYLIDAE             Boana ericae (Caramashi & Cruz, 2000)*
# 15          HYLIDAE                          Boana goiana (Lutz, 1968)
# 16          HYLIDAE                   Boana lundii (Burmeister, 1956)*
# 17          HYLIDAE         Boana phaeopleura (Caramashi & Cruz, 2000)
# 18          HYLIDAE                          Boana raniceps Cope, 1862
# 19          HYLIDAE                                          Boana sp.
# 20          HYLIDAE          Pithecopus hypochondrialis (Daudin, 1800)
# 21          HYLIDAE                Pithecopus oreades (Brandão, 2002)*
# 22          HYLIDAE                 Scinax squalirostris (Lutz, 1925)*
# 23          HYLIDAE                Scinax fuscomarginatus (Lutz, 1925)
# 24          HYLIDAE                   Scinax fuscovarius (Lutz, 1925)*
# 25          HYLIDAE     Scinax rogerioi Pugliese, Baêta & Pombal, 2009
# 26          HYLIDAE                     Scinax similis (Cochran, 1952)
# 27          HYLIDAE  Scinax skaios Pombal, Carvalho, Canelas & Bast...
# 28          HYLIDAE  Scinax tigrinus Nunes, Carvalho & Fereirra, 2010*
# 29          HYLIDAE  Scinax rupestris Araujo-Vieira, Brandão & Fari...
# 30          HYLIDAE         Trachycephalus typhonius (Linnaeus, 1758)*
# 31  LEPTODACTYLIDAE         Adenomera cotuba Carvalho & Giaretta, 2013
# 32  LEPTODACTYLIDAE       Adenomera juikitam Carvalho & Giaretta, 2013
# 33  LEPTODACTYLIDAE          Adenomera saci Carvalho & Giaretta, 2013*
# 34  LEPTODACTYLIDAE   Leptodactylus furnarius Sazima & Bokermann, 1978
# 35  LEPTODACTYLIDAE            Leptodactylus fuscus (Schneider, 1799)*
# 36  LEPTODACTYLIDAE  Leptodactylus labyrinthicus (Spix, 1824)* - re...
# 37  LEPTODACTYLIDAE               Leptodactylus mystaceus (Spix, 1824)
# 38  LEPTODACTYLIDAE       Leptodactylus mystacinus (Burmeister, 1861)*
# 39  LEPTODACTYLIDAE     Leptodactylus sertanejo Giaretta & Costa, 2007
# 40  LEPTODACTYLIDAE              Leptodactylus syphax Bokermann, 1969*
# 41  LEPTODACTYLIDAE      Leptodactylus tapiti Sazima & Bokermann, 1978
# 42  LEPTODACTYLIDAE              Leptodactylus latrans (Steffen, 1815)
# 43  LEPTODACTYLIDAE                    Leptodactylus aff. cunicularius
# 44  LEPTODACTYLIDAE              Physalaemus centralis Bokermann, 1926
# 45  LEPTODACTYLIDAE               Physalaemus cuvieri Fitzinger, 1826*
# 46  LEPTODACTYLIDAE           Pseudopaludicola mystacalis (Cope, 1887)
# 47  LEPTODACTYLIDAE              Pseudopaludicola saltica (Cope, 1887)
# 48  LEPTODACTYLIDAE    Pseudopaludicola ternetzi Miranda-Ribeiro, 1920
# 49     MICROHYLIDAE     Elachistocleis cesarii Miranda-Ribeiro, 1920)*
# 50     MICROHYLIDAE                                 Elachistocleis sp.
# 51  ODONTOPHRYNIDAE   Odontophrynus cultripes Reinhardt & Lutken, 1862
# 52  ODONTOPHRYNIDAE            Odontophrynus salvatori Caramashi, 1996
# 53  ODONTOPHRYNIDAE     Proceratophrys goyana (Miranda-Ribeiro, 1937)*
# 54  ODONTOPHRYNIDAE  Proceratophrys rotundipalpebra Martins & Giare...
#
#                                       vernacularNames Endêmico (Chapada)  \
# 0                                                                    não
# 1                                     Cururu de couro                não
# 2                                              Cururu                não
# 3                                              Cururu                não
# 4                                     Cururu-vermelho                não
# 5                                         Sapo cururu                não
# 6                                    Rãzinha da chuva                não
# 7                                         Sapo flecha                não
# 8                              Perereca-verde-da-mata                não
# 9                                      Falsa perereca                não
# 10                              Pererequinha do Brejo                não
# 11                                 pererequinha-miúda                não
# 12                            Perereca de Lagoa Santa                não
# 13                        Perereca de Pintas Amarelas                não
# 14                                Perereca-Chapadeira                sim
# 15                                 Perereca de Pijama                não
# 16                                     Perereca usina                não
# 17                         Perereca de Listras Marrom                sim
# 18              Perereca-do-Chaco; Perereca Chaquenha                não
# 19                                           perereca                NaN
# 20                                    Perereca-macaco                não
# 21                               Perereca do planalto                não
# 22                                  Perereca nariguda                não
# 23                              Pererequinha do brejo                não
# 24                    Perereca de banheiro; Rapa-cuia                não
# 25                                           Perereca                não
# 26                                           Perereca                não
# 27                                   Perereca-do-frio                não
# 28                                     Perereca tigre                não
# 29                            Pererequinha-das-rochas                sim
# 30                                   Perereca babenta                não
# 31                                     Rãzinha-sumida                não
# 32                                  Rãzinha-verrucosa                sim
# 33                                            Rã saci                não
# 34                                   Rãzinha-cavadora                não
# 35                          Rã assobiadora/biscateira                não
# 36                                         Rã pimenta                não
# 37                                   Rã-bigode-branco                não
# 38  Rã-de-bigode (sugerido), Rã-assobiadora (Maffe...                não
# 39                                       Rã-do-sertão                não
# 40                                      Rã das pedras                não
# 41                                  Rãzinha-cavadeira                sim
# 42                                        Rã-manteiga                não
# 43                                   Rãzinha-forneira                NaN
# 44                   Rã fantasma; rã gatinho; rã ingá                não
# 45                       Rã cachorro; Foi-gol-não-foi                não
# 46                                      Rãzinha-grilo                não
# 47                                  Rãzinha-saltadora                não
# 48                                           Rã-grilo                não
# 49                                     Apito-do-brejo                não
# 50                             Apito-do-brejo-pequeno                NaN
# 51                                  Sapo-verruga-liso                não
# 52         Sapo-verruguinha; Sapo-caminho-de-Salvator                não
# 53                                       Sapo verruga                não
# 54                   Sapo-verruga-de-palpebra-redonda                sim
#
#    Endêmico (Cerrado)      Red List Diagnose escrita  \
# 0                 sim            NT               ok
# 1                 não            LC               ok
# 2                 sim  não avaliada               ok
# 3                 não            LC              NaN
# 4                 sim            LC               ok
# 5                 não            LC               ok
# 6                 sim            LC               ok
# 7                 sim            LC               ok
# 8                 sim  não avaliada               ok
# 9                 sim            LC               ok
# 10                sim            LC               ok
# 11                não            LC               ok
# 12                sim            LC               ok
# 13                não            LC               ok
# 14                sim            DD               ok
# 15                sim            LC               ok
# 16                sim            LC               ok
# 17                sim            DD               ok
# 18                não            LC               ok
# 19                NaN           NaN              NaN
# 20                não            LC               ok
# 21                sim            DD               ok
# 22                não            LC               ok
# 23                não            LC               ok
# 24                não            LC               ok
# 25                sim           NaN               ok
# 26                não            LC               ok
# 27                sim           NaN               ok
# 28                sim            LC               ok
# 29                sim  não avaliada               ok
# 30                não            LC               ok
# 31                sim            LC               ok
# 32                sim  não avaliada               ok
# 33                sim  não avaliada               ok
# 34                sim            LC               ok
# 35                não            LC               ok
# 36                não            LC               ok
# 37                não            LC               ok
# 38                não            LC               ok
# 39                sim            LC               ok
# 40                sim            LC               ok
# 41                sim            DD               ok
# 42                não            LC               ok
# 43                NaN           NaN              NaN
# 44                sim            LC               ok
# 45                não            LC               ok
# 46                não            LC               ok
# 47                sim            LC               ok
# 48                sim            LC               ok
# 49                sim  não avaliada               ok
# 50                NaN           NaN              NaN
# 51                sim            LC               ok
# 52                sim            DD               ok
# 53                sim            LC               ok
# 54                sim  não avaliada               ok
#
#    Habitat de vida (mata ou floresta/area aberta/pedras)*  \
# 0      Floresta: mata de galeria com ambiente rochoso
# 1                          Mata de galeria e cerradão
# 2                 cerrado (Ce) e areas alteradas (Aa)
# 3    cerrado (Ce) e areas alteradas (Aa), mata ciliar
# 4   areas abertas (Of), Cerrado (Ce), floresta (Fh...
# 5   areas abertas (Of), Cerrado (Ce), floresta (Fh...
# 6                        floresta (Fh), cerrado, (Ce)
# 7                    areas abertas (Of), Cerrado (Ce)
# 8                                       floresta (Fh)
# 9    areas abertas (Of), Cerrado (Ce) e floresta (Fh)
# 10                   areas abertas (Of), Cerrado (Ce)
# 11  areas abertas (Of), Cerrado (Ce) e áreas alter...
# 12  areas abertas (Of), Cerrado (Ce) e áreas alter...
# 13  areas abertas (Of), Cerrado (Ce) e áreas alter...
# 14                       floresta (Fh) e Cerrado (Ce)
# 15                                    Floresta (Fh)
# 16                                    Floresta (Fh)
# 17                                    Floresta (Fh)
# 18  areas abertas (Of), Floresta (Fh)  e áreas alt...
# 19                                                NaN
# 20  areas abertas (Of), Cerrado (Ce), floresta (Fh...
# 21                   areas abertas (Of), Cerrado (Ce)
# 22                   areas abertas (Of), Cerrado (Ce)
# 23  areas abertas (Of), Cerrado (Ce), areas altera...
# 24  areas abertas (Of), Cerrado (Ce), floresta (Fh...
# 25                                 areas abertas (Of)
# 26  areas abertas (Of), Cerrado (Ce), floresta (Fh...
# 27    areas abertas (Of), Cerrado (Ce), floresta (Fh)
# 28                   areas abertas (Of), Cerrado (Ce)
# 29                   areas abertas (Of), Cerrado (Ce)
# 30               floresta (Fh) e áreas alteradas (Aa)
# 31                   areas abertas (Of), Cerrado (Ce)
# 32                  Areas abertas (Of), Cerrado(Ce)
# 33                  areas abertas (Of), Cerrado(Ce)
# 34                                 areas abertas (Of)
# 35  areas abertas (Of), Cerrado (Ce), floresta (Fh...
# 36  areas abertas (Of), Cerrado (Ce), floresta (Fh...
# 37    areas abertas (Of), Cerrado (Ce), floresta (Fh)
# 38                   areas abertas (of), cerrado (ce)
# 39                   areas abertas (of), cerrado (ce)
# 40                   areas abertas (of), cerrado (ce)
# 41                   areas abertas (of), cerrado (ce)
# 42  areas abertas (of); cerrado (ce); areas altera...
# 43                                                NaN
# 44                   áreas abertas (of); cerrado (ce)
# 45  areas abertas (of); cerrado (ce); areas altera...
# 46                   areas abertas (of); cerrado (ce)
# 47  areas abertas (of); cerrado (ce); habitats flo...
# 48  areas abertas (of); cerrado (ce); areas altera...
# 49  areas abertas (of); cerrado (ce); areas altera...
# 50                                                NaN
# 51                        Cerrado (Ce); floresta (Fh)
# 52                   áreas abertas (of); cerrado (ce)
# 53    areas abertas (Of), Cerrado (Ce), floresta (Fh)
# 54                   areas abertas (Of), Cerrado (Ce)
#
#    Categorias fitofisionomias (guia)    Altitude            habitat_breeding  \
# 0                                 FG         NaN              terrestre (Tr)
# 1                             FG, CE         NaN                Lêntico (Le)
# 2                            CSS, AA         NaN                Lêntico (Le)
# 3                        FC, CSS, AA   200-1500m              terrestre (Tr)
# 4          FC, FG, CE, CSS, C, V, AA  430-1400 m  Lêntico (Le) e Lótico (Lo)
# 5                      CSS, C, V, AA         NaN  Lêntico (Le) e Lótico (Lo)
# 6                     FC, FG, CE,CSS         NaN              terrestre (Tr)
# 7                         SCR, C, CR         NaN              terrestre (Tr)
# 8                             FC, FG         NaN                 Lótico (Lo)
# 9                         CR, FG, FC         NaN                 Lótico (Lo)
# 10                            C, CSS         NaN                Lêntico (Le)
# 11                        C, CSS, AA         NaN                Lêntico (Le)
# 12                        C, CSS, AA         NaN                Lêntico (Le)
# 13                        C, CSS, AA         NaN                Lêntico (Le)
# 14                       FC, FG, CSS         NaN                 Lótico (Lo)
# 15                            FC, FG         NaN                 Lótico (Lo)
# 16                         FC, FG, C         NaN                 Lótico (Lo)
# 17                            FC, FG         NaN                 Lótico (Lo)
# 18                     C, FC, FG, AA         NaN                Lêntico (Le)
# 19                               NaN         NaN                         NaN
# 20                C, CDD, FC, FG, AA         NaN                Lêntico (Le)
# 21                            C, CSS         NaN                 Lótico (Lo)
# 22                            C, CSS         NaN                Lêntico (Le)
# 23                        C, CSS, AA         NaN                Lêntico (Le)
# 24                C, CSS, FC, FG, AA         NaN                Lêntico (Le)
# 25                                 C       >900m                Lêntico (Le)
# 26                C, CSS, FG, FC, AA         NaN                Lêntico (Le)
# 27                    C, CSS, FC, FG       >700m                 Lótico (Lo)
# 28                            C, CSS         NaN                Lêntico (Le)
# 29                        C, CSS, CR       1200m                         NaN
# 30                        FC, FG, AA         NaN                Lêntico (Le)
# 31                            C, CSS         NaN                Lêntico (Le)
# 32                            C, CSS         NaN                Lêntico (Le)
# 33                            C, CSS         NaN                Lêntico (Le)
# 34                                 C         NaN                Lêntico (Le)
# 35             C, CSS, AA, FC, FG, V         NaN                Lêntico (Le)
# 36             C, CSS, AA, FC, FG, V         NaN                Lêntico (Le)
# 37                            C, CSS         NaN                Lêntico (Le)
# 38                            C, CSS         NaN                Lêntico (Le)
# 39                            C, CSS         NaN                Lêntico (Le)
# 40                        C, CSS, AA         NaN                Lêntico (Le)
# 41                            C, CSS       1300m                 Lótico (Lo)
# 42             C, CSS, AA, FC, FG, V         NaN                Lêntico (Le)
# 43                               NaN  1110-1500m                         NaN
# 44                          CSS,C, V         NaN                         NaN
# 45             C, CSS, AA, FC, FG, V         NaN                Lêntico (Le)
# 46                        C, CE, CSS         NaN                Lêntico (Le)
# 47                    C, CSS, FC, FG         NaN                Lêntico (Le)
# 48                        C, CSS, AA         NaN                Lêntico (Le)
# 49                        C, CSS, AA         NaN                Lêntico (Le)
# 50                               NaN         NaN                         NaN
# 51                        CE, CSS, C         NaN                Lêntico (Le)
# 52                        CE, CSS, C         NaN                         NaN
# 53                        CE, CSS, C         NaN                 Lótico (Lo)
# 54                        CE, CSS, C         NaN                 Lótico (Lo)
#
#                     Poleiro (tipical calling perch)*   \
# 0                                      Terrestre (Te)
# 1                                      Terrestre (Te)
# 2                                      Terrestre (Te)
# 3                                      Terrestre (Te)
# 4                                      Terrestre (Te)
# 5                                      Terrestre (Te)
# 6                                      Terrestre (Te)
# 7                                      Terrestre (Te)
# 8          Arbustos baixos (Hb) e arbustos altos (Lb)
# 9               Terrestre (Te) e arbustos baixos (Lb)
# 10                                         Grama (Gr)
# 11                  arbustos baixos (Lb) e Grama (Gr)
# 12                                         Grama (Gr)
# 13  arbustos baixos (Lb), arbustos altos (Hb) e Gr...
# 14          arbustos baixos (Lb), arbustos altos (Hb)
# 15          arbustos baixos (Lb), arbustos altos (Hb)
# 16          arbustos baixos (Lb), arbustos altos (Hb)
# 17          arbustos baixos (Lb), arbustos altos (Hb)
# 18                               arbustos baixos (Lb)
# 19                                                NaN
# 20  arbustos baixos (Lb), arbustos altos (Hb), Ter...
# 21  arbustos baixos (Lb), Terrestre (Te) e Grama (Gr)
# 22                                         Grama (Gr)
# 23                  Grama (Gr) e arbustos baixos (Lb)
# 24  arbustos baixos (Lb), arbustos altos (Hb), Gra...
# 25                        Grama (Gr) e Terrestre (Tr)
# 26  arbustos baixos (Lb), arbustos altos (Hb), Gra...
# 27              arbustos baixos (Lb) e Terrestre (Tr)
# 28                                         Grama (Gr)
# 29                                     Terrestre (Te)
# 30          arbustos baixos (Lb), arbustos altos (Hb)
# 31                                     Terrestre (Te)
# 32                                     Terrestre (Te)
# 33                                     Terrestre (Te)
# 34                                     Terrestre (Te)
# 35                                     Terrestre (Te)
# 36                                     Terrestre (Te)
# 37                                     Terrestre (Te)
# 38                                     Terrestre (Te)
# 39                                     Terrestre (Te)
# 40                                     Terrestre (Te)
# 41                                     Terrestre (Te)
# 42                                     Terrestre (Te)
# 43                                                NaN
# 44                                     Terrestre (Te)
# 45                                     Terrestre (Te)
# 46                                     Terrestre (Te)
# 47                                     Terrestre (Te)
# 48                                     Terrestre (Te)
# 49                                     Terrestre (Te)
# 50                                                NaN
# 51                                     Terrestre (Te)
# 52                                     Terrestre (Te)
# 53                                     Terrestre (Te)
# 54                                     Terrestre (Te)
#
#    Atividade (noturno/diurno) Tamanho real (mm) - fêmea  \
# 0                      diurno                   16.8-17
# 1                     noturno                       180
# 2                     noturno                     49-73
# 3                     noturno                        44
# 4                     noturno                        90
# 5                     noturno                   150-200
# 6                      diurno                     23-30
# 7                      diurno                     20-24
# 8                     noturno                      33.7
# 9                     noturno                 60.2-61.6
# 10                    noturno                     23-26
# 11                    noturno                     18-23
# 12                    noturno                     21-25
# 13                    noturno                        50
# 14                    noturno                        30
# 15                    noturno                        32
# 16                    noturno                        65
# 17                    noturno                       NaN
# 18                    noturno                        45
# 19                        NaN                     30-45
# 20                    noturno                     30-45
# 21                    noturno                       NaN
# 22                    noturno                        25
# 23                    noturno                     15-27
# 24                    noturno                        41
# 25                    noturno                   28-34.5
# 26                    noturno                     35-40
# 27                    noturno                 13.5-22.2
# 28                    noturno                 28.4-30.8
# 29                    noturno                 26.7-31.7
# 30           noturno e diurno                    93-114
# 31                    noturno                 18.6-20.5
# 32                    noturno                        19
# 33          noturno e diurno                  20.1-22.5
# 34                    noturno                     57-72
# 35                    noturno                     32-54
# 36                    noturno                       155
# 37                    noturno                 40.6-46.6
# 38                    noturno              46,9 a 70,0
# 39                    noturno                      54.3
# 40                    noturno                    70–90
# 41                    noturno                35.8–41.4
# 42                    noturno                        80
# 43                        NaN                     40-45
# 44                    noturno               29,06-39,4
# 45                    noturno                        30
# 46                    noturno                     14-16
# 47          noturno e diurno                         16
# 48                    noturno                      20.6
# 49                    noturno                        30
# 50                        NaN                       NaN
# 51                    noturno                    45–70
# 52                    noturno                 26.8-27.8
# 53          noturno e diurno                 38.8-46.5
# 54          noturno e diurno                 30.4–39.3
#
#    Tamanho real (mm) - macho       Meses de Ocorrência    detectability  \
# 0                    16.8-17                       NaN       Muito raro
# 1                         68                       NaN             Raro
# 2                      40-71                       NaN             Raro
# 3                        NaN           chuva até março        Frequente
# 4                        NaN                  ano todo        Frequente
# 5                        NaN                  ano todo  Muito frequente
# 6                        NaN                     chuva        Frequente
# 7                        NaN                  ano todo             Raro
# 8                    30.7–36  Chuva (Dezembro a Março)             Raro
# 9                  51.9-65.3                     chuva        Frequente
# 10                       NaN                     chuva        Frequente
# 11                       NaN                  ano todo        Frequente
# 12                     18-23                     chuva  Muito frequente
# 13                       NaN                  ano todo  Muito frequente
# 14                       NaN                     chuva             Raro
# 15                       NaN                  ano todo        Frequente
# 16                       NaN                  ano todo  Muito frequente
# 17                       NaN                     chuva        Frequente
# 18                       NaN                  ano todo        Frequente
# 19                       NaN                       NaN              NaN
# 20                       NaN                  ano todo        Frequente
# 21                       NaN                     chuva             Raro
# 22                       NaN                     Chuva        Frequente
# 23                       NaN                  ano todo        Frequente
# 24                       NaN                  ano todo  Muito frequente
# 25                   25-35.6                     Chuva             Raro
# 26                       NaN                     chuva        Frequente
# 27                       NaN                     chuva             Raro
# 28                       NaN                  ano todo        Frequente
# 29                 21.9-27.7                     chuva             Raro
# 30                    70-101                  ano todo        Frequente
# 31                       NaN                     chuva             Raro
# 32                       NaN                     chuva             Raro
# 33                       NaN                     chuva             Raro
# 34                       NaN                  Ano todo        Frequente
# 35                       NaN                  Ano todo  Muito frequente
# 36                       NaN                  Ano todo  Muito frequente
# 37                   40.4-45                     chuva        Frequente
# 38              50,8 a 58,4                      chuva        Frequente
# 39                        51                     chuva             Raro
# 40                    58–83                      chuva             Raro
# 41                29.8–33.4                      chuva             Raro
# 42                       120                  Ano todo  Muito frequente
# 43                       NaN                       NaN              NaN
# 44              30,25-38,55                    set-jan  Muito frequente
# 45                        28                  Ano todo  Muito frequente
# 46                       NaN                  Ano todo  Muito frequente
# 47                       NaN                     chuva        Frequente
# 48                      17.4                     chuva        Frequente
# 49                       NaN                     chuva        Frequente
# 50                       NaN                       NaN              NaN
# 51                    50–60                 seca-chuva        frequente
# 52                 26.8-27.8                   Out-dez       frequente*
# 53                       NaN                  ano todo        Frequênte
# 54                       NaN                  Ano todo             Raro
#
#           Distribuição - SITE REUBER (espécies do DF)  \
# 0
# 1
# 2
# 3   Tocantins, Para´, Mato Grosso, Minas Gerais, a...
# 4   Espécie com ampla distribuição associada ao bi...
# 5   Espécie com ampla distribuição podendo ser enc...
# 6   Espécie restrita ao bioma Cerrado, pode ser en...
# 7   Espécie com ampla distribuição no bioma Cerrad...
# 8   Sua distribuição é no estado do DF e no Goiás,...
# 9
# 10  Espécie associada ao bioma Cerrado. Ocorre nos...
# 11  Espécie amplamente distribuída na América do S...
# 12  Espécie de ampla distribuição no Brasil centra...
# 13  Espécie de ampla distribuição ocorrendo desde ...
# 14
# 15  Espécie de ampla distribuição no Brasil Centra...
# 16  Espécie endêmica do bioma Cerrado, ocorrendo n...
# 17
# 18  No Brasil está presente em praticamente todos ...
# 19                                                NaN
# 20  É encontrada nos estados de Rondônia, Tocantin...
# 21  Espécie associada às regiões de serras e chapa...
# 22  Espécie de ampla distribuição geográfica, ocor...
# 23  Espécie de ampla distribuição podendo ser enco...
# 24  Espécie de ampla distribuição ocorrendo desde ...
# 25  Espécie associada às serras e chapadas do esta...
# 26  Espécie ocorre no Brasil e Paraguai (Conchran,...
# 27  Espécie conhecida para o Goiás e Distrito Fede...
# 28  Espécie conhecida no estados de Minas Gerais, ...
# 29
# 30  Espécie de ampla distribuição. Ocorre desde o ...
# 31
# 32  Espécie conhecida para os estados do Goiás, re...
# 33  Espécie endêmica do bioma Cerrado. Conhecida p...
# 34  Ocorre nos estados da Bahia, Tocantins, Goiás,...
# 35  Está presente em quase todo o território brasi...
# 36  Distribuição está associada às regiões de form...
# 37  Espécie com ampla distribuição, podendo ser en...
# 38  Espécie de ampla distribuição, desde o leste d...
# 39  Espécie ocorre nos estados do Goiás, Minas Ger...
# 40  A espécie possui ampla distribuição geográfica...
# 41
# 42  A táxon possui ampla distribuição, podendo oco...
# 43                                                NaN
# 44  A distribuição geográfica da espécie é ampla e...
# 45  Espécie de ampla distribuição geográfica. Ocor...
# 46  Possivelmente a espécie do gênero com a mais a...
# 47  Espécie associada ao bioma Cerrado. Ocorre na ...
# 48  Espécie conhecida para região central do Brasi...
# 49  Espécie com ampla distribuição e pode ser enco...
# 50                                                NaN
# 51  Ocorre em regiões de altitudes acima de 800 me...
# 52  Espécie associada ao planalto central goiano, ...
# 53  Espécie conhecida para o estado do Goiás, Dist...
# 54
#
#                Ameaças - SITE REUBER (espécies do DF)
# 0
# 1
# 2
# 3
# 4   Desmatamentos e remoção de hábitats constituem...
# 5                               Espécie não ameaçada.
# 6   Desmatamento e remoção de hábitats constituem ...
# 7                 Desmatamentos e remoção de habitat.
# 8
# 9
# 10                                                NaN
# 11                                Taxon não ameaçado.
# 12                                                NaN
# 13                                Taxon não ameaçado.
# 14                                                NaN
# 15                                                NaN
# 16  Exploração madeireira, construção de reservató...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  Expansão das fronteiras agropecuárias, constru...
# 22                              Espécie não ameaçada.
# 23                                                NaN
# 24                              Espécie não ameaçada.
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                              Espécie não ameaçada.
# 29
# 30                              Espécie não ameaçada.
# 31                                                NaN
# 32                                                NaN
# 33  Expansão das fronteiras agropecuárias, fragmen...
# 34                                                NaN
# 35  Exploração madeireira, construção de reservató...
# 36         Caça é uma possível ameaça para e espécie.
# 37                                                NaN
# 38  Espécie não ameaçada. Algumas das possíveis am...
# 39                                                NaN
# 40  Exploração madeireira, construção de reservató...
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                              Espécie não ameaçada.
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53  Expansão das fronteiras agropecuárias e a expl...
# 54                                                NaN

# %% [markdown]
# ### Species name, id and Authorship

# %%
df['scientificName'] = df['speciesName'].apply(lambda x: re.findall( '^\w+(?: cf.| aff.)? \w+\.?', str(x))[0])

# %%
df['scientificNameAuthorship'] = df[['speciesName','scientificName']].apply(lambda x: x[0][len(x[1]):], axis=1)
df['scientificNameAuthorship'] = df['scientificNameAuthorship'].apply(lambda x: re.findall( '[\w,\s\-&]+', str(x) )).apply(lambda x: ''.join(x).strip())

# %%
ids = df['scientificName'].str.replace('\s','-').str.replace('[.]','').str.lower()
df.insert(0, 'id', ids)

# %%
df.drop('speciesName', axis=1, inplace=True)

# %% [markdown]
# ### Family name and id

# %%
df['family'] = df['family'].apply(lambda x: x.capitalize())
df['family_id'] = df['family'].str.lower()

# %% [markdown]
# ### Vernacular name

# %%
def extractVernacularNames(string):
    names = re.split('/|;|,',string)
    names = [ n.strip().replace(' ','-').capitalize() for n in names ]
    if len(names)==1 and names[0]=='':
        return []
    else:
        return names

# %%
df['vernacularNames'] = df['vernacularNames'].apply(extractVernacularNames)

# %% [markdown]
# ### Red list

# %%
df['Red List'] = df['Red List'].str.lower()
df.loc[ df['Red List']=='não avaliada','Red List']='ne'

# %%
df = pd.get_dummies(data=df, prefix='redlist', columns=['Red List'])

# %% [markdown]
# ### Endemicidade

# %%
df['endemic_cerrado'] = df['Endêmico (Cerrado)'].apply(lambda x: 1 if x=='sim' else 0)
df['endemic_chapada'] = df['Endêmico (Chapada)'].apply(lambda x: 1 if x=='sim' else 0)
df.drop('Endêmico (Chapada)', axis=1, inplace=True)
df.drop('Endêmico (Cerrado)', axis=1, inplace=True)

# %%
# Helpers

getInsideParentheses = lambda x: [ str.lower(e) for e in re.findall( '\((.{0,5})\)', str(x) ) ]

# %% [markdown]
# ### Detectability

# %%
df['detectability'] = df['detectability']\
    .str.replace('[^\w]','')\
    .str.replace('ê','e')\
    .str.lower()

# %%
subst_dict = {
    'muitofrequente': 'ff',
    'frequente':'f',
    'raro': 'r',
    'muitoraro': 'rr'
}

df['detectability'] = df['detectability'].apply(lambda x: subst_dict[x] if x is not np.NaN else x)
df = pd.get_dummies(df, prefix='detectability',columns=['detectability'])

# %% [markdown]
# ### Poleiro

# %%
df['poleiro'] = df['Poleiro (tipical calling perch)* '].apply( getInsideParentheses )
df.drop('Poleiro (tipical calling perch)* ', axis=1, inplace=True)

# %%
poleiro_types = list(set( el for ls in df['poleiro'] for el in ls))

# %%
for tp in poleiro_types:
    df[f'tcp_{tp}'] = df['poleiro'].apply(lambda x: 1 if f'{tp}' in x else 0)

# %%
df.drop('poleiro', axis=1, inplace=True)

# %% [markdown]
# ### Habitat breeding

# %%
matches = df['habitat_breeding'].str.lower().str.extractall('\((\w+)\)')
hb_dummies = pd.get_dummies(matches, prefix="habitat_breeding").groupby(level=0).sum()

# %%
hb_dummies = hb_dummies.reindex(df.index).fillna(0).astype(int)

# %%
df = pd.concat([df,hb_dummies], axis=1)

# %%
df.drop('habitat_breeding',axis=1, inplace=True)

# %% [markdown]
# ### Phytophysiognomies categoricals

# %%
df.rename({'Categorias fitofisionomias (guia)': 'phytos'}, axis=1, inplace=True)

# %%
replaces = {
    'cdd':'css',
    'fg':'mg',
    'fc':'mc',
    'ce':'cc',
    'css':'ce',
    'sc':'cet',
    'scr':'cer',
    'c': 'cal',
    'cr':'car',
    'aa':'ur',
    'v':'ve'
} 
df['phytos'] = df['phytos'].str.lower().str.strip().str.split('\s*,\s*')\
    .apply(lambda x: [replaces.get(i,i) for i in x] if isinstance(x,list) else '')\
    .str.join(',')

# %%
df['phytos']
# Out:
# 0                        mg
# 1                     mg,cc
# 2                     ce,ur
# 3                  mc,ce,ur
# 4     mc,mg,cc,ce,cal,ve,ur
# 5              ce,cal,ve,ur
# 6               mc,mg,cc,ce
# 7               cer,cal,car
# 8                     mc,mg
# 9                 car,mg,mc
# 10                   cal,ce
# 11                cal,ce,ur
# 12                cal,ce,ur
# 13                cal,ce,ur
# 14                 mc,mg,ce
# 15                    mc,mg
# 16                mc,mg,cal
# 17                    mc,mg
# 18             cal,mc,mg,ur
# 19
# 20         cal,css,mc,mg,ur
# 21                   cal,ce
# 22                   cal,ce
# 23                cal,ce,ur
# 24          cal,ce,mc,mg,ur
# 25                      cal
# 26          cal,ce,mg,mc,ur
# 27             cal,ce,mc,mg
# 28                   cal,ce
# 29               cal,ce,car
# 30                 mc,mg,ur
# 31                   cal,ce
# 32                   cal,ce
# 33                   cal,ce
# 34                      cal
# 35       cal,ce,ur,mc,mg,ve
# 36       cal,ce,ur,mc,mg,ve
# 37                   cal,ce
# 38                   cal,ce
# 39                   cal,ce
# 40                cal,ce,ur
# 41                   cal,ce
# 42       cal,ce,ur,mc,mg,ve
# 43
# 44                ce,cal,ve
# 45       cal,ce,ur,mc,mg,ve
# 46                cal,cc,ce
# 47             cal,ce,mc,mg
# 48                cal,ce,ur
# 49                cal,ce,ur
# 50
# 51                cc,ce,cal
# 52                cc,ce,cal
# 53                cc,ce,cal
# 54                cc,ce,cal
# Name: phytos, dtype: object

# %% [markdown]
# ### Habitat

# %%
df['habitat'] = df['Habitat de vida (mata ou floresta/area aberta/pedras)*'].apply( getInsideParentheses)
df.drop('Habitat de vida (mata ou floresta/area aberta/pedras)*', axis=1, inplace=True)

# %%
habitat_types = list(set( el for ls in df['habitat'] for el in ls ))

# %%
for tp in habitat_types:
    df[f'habitat_{tp}'] = df['habitat'].apply(lambda x: 1 if f'{tp}' in x else 0)

# %%
df.drop('habitat', axis=1, inplace=True)

# %% [markdown]
# ### Atividade

# %%
df['Atividade (noturno/diurno)'].value_counts()
# Out:
# noturno              44
# noturno e diurno      4
# diurno                3
# noturno e diurno      1
# Name: Atividade (noturno/diurno), dtype: int64

# %%
df['atividade_diu'] = df['Atividade (noturno/diurno)'].apply(lambda x: 1 if 'diurno' in str(x) else 0)
df['atividade_not'] = df['Atividade (noturno/diurno)'].apply(lambda x: 1 if 'noturno' in str(x) else 0)
df.drop('Atividade (noturno/diurno)', axis=1, inplace=True)

# %%
df['Ameaças - SITE REUBER (espécies do DF)'][5]
# Out:
# 'Espécie não ameaçada.'

# %% [markdown]
# ### Tamanho

# %%
df['tamanho_femea'] = df['Tamanho real (mm) - fêmea'].apply(lambda x: re.findall( '([0-9\.]+)' , str(x).replace(',','.')))
df['tamanho_macho'] = df['Tamanho real (mm) - macho'].apply(lambda x: re.findall( '([0-9\.]+)' , str(x).replace(',','.')))

# %%
df['tamanho_femea_med'] = df['tamanho_femea'].apply( lambda l: sum([float(i) for i in l])/len(l) if len(l)>0 else None )
df['tamanho_macho_med'] = df['tamanho_macho'].apply( lambda l: sum([float(i) for i in l])/len(l) if len(l)>0 else None )

# %%
#df['tamanho_femea_min'] = df['tamanho_femea'].apply( lambda x: min([ float(i) for i in x]) if len(x) > 0 else None)
#df['tamanho_femea_max'] = df['tamanho_femea'].apply( lambda x: max([ float(i) for i in x]) if len(x) > 0 else None)
#df['tamanho_macho_min'] = df['tamanho_macho'].apply( lambda x: min([ float(i) for i in x]) if len(x) > 0 else None)
#df['tamanho_macho_max'] = df['tamanho_macho'].apply( lambda x: max([ float(i) for i in x]) if len(x) > 0 else None)

#df['tamanho_macho_max'].replace(np.NaN, df['tamanho_femea_max'], inplace=True)
#df['tamanho_macho_min'].replace(np.NaN, df['tamanho_femea_min'], inplace=True)
#df['tamanho_femea_max'].replace(np.NaN, df['tamanho_macho_max'], inplace=True)
#df['tamanho_femea_min'].replace(np.NaN, df['tamanho_femea_min'], inplace=True)

# %%
df.drop('tamanho_femea', axis=1, inplace=True)
df.drop('tamanho_macho', axis=1, inplace=True)
df.drop('Tamanho real (mm) - fêmea', axis=1, inplace=True)
df.drop('Tamanho real (mm) - macho', axis=1, inplace=True)

# %%
df['tamanho_macho_med'].replace(np.NaN, df['tamanho_femea_med'], inplace=True)
df['tamanho_femea_med'].replace(np.NaN, df['tamanho_macho_med'], inplace=True)
df['tamanho_med'] = df[['tamanho_macho_med','tamanho_femea_med']].mean(axis=1)

# %% [markdown]
# ### Meses de ocorrência

# %% [markdown]
# 1. Extract month ranges from strings

# %%
import unicodedata

normalize_str = lambda x: unicodedata.normalize('NFKD',x).encode('ascii', errors='ignore').decode('utf-8').lower().strip()
months=['janeiro','fevereiro','marco','abril','maio','junho','julho','agosto','setembro','outubro','novembro','dezembro',
        'jan','fev','mar','abr','mai','jun','jul','ago','set','out','nov','dez']

# %%
df['Meses de Ocorrência'] = df['Meses de Ocorrência'].apply(lambda x: normalize_str(x) if pd.notnull(x) else x)\
    .replace('chuva','out-mar')\
    .replace('ano todo', 'jan-dez')\
    .replace('seca-chuva','jan-dez')\
    .replace('chuva ate marco','out-mar')\
    .str.findall("("+"|".join(months)+")")\
    .apply(lambda x: [ i[:3] for i in x] if isinstance(x,list) else x)\
    .str.join(sep='-')\

# %%
def occurrence_months(m_start, m_end):
    d=['jan','fev','mar','abr','mai','jun','jul','ago','set','out','nov','dez']
    idx_mstart = d.index(m_start)
    idx_mend = d.index(m_end)
    
    if idx_mstart > idx_mend:
        return d[idx_mstart:]+d[:idx_mend+1]
    else:
        return d[idx_mstart:idx_mend+1]
    
    
def months_to_array(mths):
    d=['jan','fev','mar','abr','mai','jun','jul','ago','set','out','nov','dez']
    return [ 1 if i in mths else 0 for i in d ]

# %%
df['month_vec'] = df['Meses de Ocorrência'].str.split('-').apply(
    lambda x: months_to_array(occurrence_months(*x)) if isinstance(x,list) else [0 for i in range(12)]
)

# %% [markdown]
# ### Temporarily remove unused fields

# %%
df.drop('Distribuição - SITE REUBER (espécies do DF)', axis=1, inplace=True)
df.drop('Ameaças - SITE REUBER (espécies do DF)', axis=1, inplace=True)

# %% [markdown]
# ### Remove unwanted species

# %%
spp_to_remove = ['boana-sp','leptodactylus-aff-cunicularius','elachistocleis-sp']

# %%
df = df[ df['id'].apply(lambda x: x not in spp_to_remove) ]

# %% [markdown]
# ### Sort dataframe by Family and id

# %%
df = df.sort_values(by=['family','id'])

# %% [markdown]
# ### Write to json

# %%
species_data_path = '../_data/species.json'

d = df.to_dict(orient='records')

with open(species_data_path, 'w') as f:
    json.dump(d, f,indent=1, ensure_ascii=False)
