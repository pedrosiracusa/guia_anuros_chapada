# %%
import pandas as pd
import numpy as np
import re
import json

# %%
pd.set_option('display.max_columns',50)

# %%
dataFile = './speciesdata.csv'

# %%
excludedCols = ['Responsável','Guia','Folder','Artigo','Família.1', 
                'Glossário','Fotos adultos','Fotos girinos',
                'Vídeos','Áudios', 'Diagnose','DOI' ]

df = pd.read_csv(dataFile, usecols=lambda x: x not in excludedCols)

# %%
# Drop every row after the one containing only null values
nullrow = df[df.apply(lambda x: all(x.isnull()), axis=1)].index[0]
df.drop(axis=1, index=range( nullrow,df.shape[0] ), inplace=True)

# %%
df.drop('Red List.1', axis=1, inplace=True)

# %%
df.rename( {'Espécie': 'speciesName', 
            'Família': 'family',
            'Postura dos ovos (habitat breeding)*': 'habitat_breeding',
            'Chances de encontros (muito raro/raro/frequente/muito frequente)': 'detectability',
            'Nome Comum': 'vernacularNames'}, axis=1, inplace=True)

# %%
df.replace('^-$', '', inplace=True, regex=True)

# %%
df
# Out:
#              family                                        speciesName  \
# 0      AROMOBATIDAE                Allobates goianus (Bokermann, 1975)
# 1         BUFONIDAE                  Rhaebo guttatus (Schneider, 1799)
# 2         BUFONIDAE          Rhinella mirandaribeiroi (Gallardo, 1965)
# 3         BUFONIDAE                   Rhinella rubescens (Lutz, 1925)*
# 4         BUFONIDAE                Rhinella schneideri (Werner, 1894)*
# 5    CRAUGASTORIDAE      Barycholos ternetzi (Miranda- Ribeiro, 1937)*
# 6     DENDROBATIDAE                  Ameerega flavopicta (Lutz, 1925)*
# 7           HYLIDAE  Aplastodiscus lutzorum (Berneck, Giaretta, Bra...
# 8           HYLIDAE  Bokermannohyla pseudopseudis (Miranda-Ribeiro,...
# 9           HYLIDAE      Dendropsophus jimi (Napoli & Caramashi, 1999)
# 10          HYLIDAE              Dendropsophus minutus (Peters, 1872)*
# 11          HYLIDAE  Dendropsophus rubicundulus (Reinhardt & Lutken...
# 12          HYLIDAE                   Boana albopunctata Dubois, 2017*
# 13          HYLIDAE             Boana ericae (Caramashi & Cruz, 2000)*
# 14          HYLIDAE                          Boana goiana (Lutz, 1968)
# 15          HYLIDAE                   Boana lundii (Burmeister, 1956)*
# 16          HYLIDAE         Boana phaeopleura (Caramashi & Cruz, 2000)
# 17          HYLIDAE                          Boana raniceps Cope, 1862
# 18          HYLIDAE                                          Boana sp.
# 19          HYLIDAE          Pithecopus hypochondrialis (Daudin, 1800)
# 20          HYLIDAE                Pithecopus oreades (Brandão, 2002)*
# 21          HYLIDAE            Scinax aff. squalirostris (Lutz, 1925)*
# 22          HYLIDAE                Scinax fuscomarginatus (Lutz, 1925)
# 23          HYLIDAE                   Scinax fuscovarius (Lutz, 1925)*
# 24          HYLIDAE     Scinax rogerioi Pugliese, Baêta & Pombal, 2009
# 25          HYLIDAE                     Scinax similis (Cochran, 1952)
# 26          HYLIDAE  Scinax skaios Pombal, Carvalho, Canelas & Bast...
# 27          HYLIDAE  Scinax tigrinus Nunes, Carvalho & Fereirra, 2010*
# 28          HYLIDAE  Scinax rupestris Araujo-Vieira, Brandão & Fari...
# 29          HYLIDAE         Trachycephalus typhonius (Linnaeus, 1758)*
# 30  LEPTODACTYLIDAE         Adenomera cotuba Carvalho & Giaretta, 2013
# 31  LEPTODACTYLIDAE       Adenomera juikitam Carvalho & Giaretta, 2013
# 32  LEPTODACTYLIDAE          Adenomera saci Carvalho & Giaretta, 2013*
# 33  LEPTODACTYLIDAE   Leptodactylus furnarius Sazima & Bokermann, 1978
# 34  LEPTODACTYLIDAE            Leptodactylus fuscus (Schneider, 1799)*
# 35  LEPTODACTYLIDAE  Leptodactylus labyrinthicus (Spix, 1824)* - re...
# 36  LEPTODACTYLIDAE               Leptodactylus mystaceus (Spix, 1824)
# 37  LEPTODACTYLIDAE       Leptodactylus mystacinus (Burmeister, 1861)*
# 38  LEPTODACTYLIDAE     Leptodactylus sertanejo Giaretta & Costa, 2007
# 39  LEPTODACTYLIDAE              Leptodactylus syphax Bokermann, 1969*
# 40  LEPTODACTYLIDAE      Leptodactylus tapiti Sazima & Bokermann, 1978
# 41  LEPTODACTYLIDAE              Leptodactylus latrans (Steffen, 1815)
# 42  LEPTODACTYLIDAE                    Leptodactylus aff. cunicularius
# 43  LEPTODACTYLIDAE              Physalaemus centralis Bokermann, 1926
# 44  LEPTODACTYLIDAE               Physalaemus cuvieri Fitzinger, 1826*
# 45  LEPTODACTYLIDAE           Pseudopaludicola mystacalis (Cope, 1887)
# 46  LEPTODACTYLIDAE              Pseudopaludicola saltica (Cope, 1887)
# 47  LEPTODACTYLIDAE    Pseudopaludicola ternetzi Miranda-Ribeiro, 1920
# 48     MICROHYLIDAE     Elachistocleis cesarii Miranda-Ribeiro, 1920)*
# 49     MICROHYLIDAE                                 Elachistocleis sp.
# 50  ODONTOPHRYNIDAE   Odontophrynus cultripes Reinhardt & Lutken, 1862
# 51  ODONTOPHRYNIDAE            Odontophrynus salvatori Caramashi, 1996
# 52  ODONTOPHRYNIDAE     Proceratophrys goyana (Miranda-Ribeiro, 1937)*
# 53  ODONTOPHRYNIDAE  Proceratophrys rotundipalpebra Martins & Giare...
#
#                                       vernacularNames Endêmico (Chapada)  \
# 0                                                                    não
# 1                                     Cururu de couro                não
# 2                                                                    não
# 3                                   Cururu do cerrado                não
# 4                                         Sapo cururu                não
# 5                                    Rãzinha da chuva                não
# 6                                         Sapo flecha                não
# 7                              Perereca-verde-da-mata                não
# 8                                      Falsa perereca                não
# 9                               Pererequinha do Brejo                não
# 10                                 pererequinha-miúda                não
# 11                            Perereca de Lagoa Santa                não
# 12                        Perereca de Pintas Amarelas                não
# 13                                Perereca-Chapadeira                sim
# 14                                 Perereca de Pijama                não
# 15                                     Perereca usina                não
# 16                         Perereca de Listras Marrom                sim
# 17              Perereca-do-Chaco; Perereca Chaquenha                não
# 18                                           perereca                NaN
# 19                                    Perereca-macaco                não
# 20                               Perereca do planalto                não
# 21                                  Perereca nariguda                não
# 22                              Pererequinha do brejo                não
# 23                    Perereca de banheiro; Rapa-cuia                não
# 24                                           Perereca                não
# 25                                           Perereca                não
# 26                                   Perereca-do-frio                não
# 27                                     Perereca tigre                não
# 28                            Pererequinha-das-rochas                sim
# 29                                   Perereca babenta                não
# 30                                     Rãzinha-sumida                não
# 31                                  Rãzinha-verrucosa                sim
# 32                                            Rã saci                não
# 33                                   Rãzinha-cavadora                não
# 34                          Rã assobiadora/biscateira                não
# 35                                         Rã pimenta                não
# 36                                   Rã-bigode-branco                não
# 37  Rã-de-bigode (sugerido), Rã-assobiadora (Maffe...                não
# 38                                       Rã-do-sertão                não
# 39                                      Rã das pedras                não
# 40                                  Rãzinha-cavadeira                sim
# 41                                        Rã-manteiga                não
# 42                                   Rãzinha-forneira                NaN
# 43                   Rã fantasma; rã gatinho; rã ingá                não
# 44                       Rã cachorro; Foi-gol-não-foi                não
# 45                                      Rãzinha-grilo                não
# 46                                  Rãzinha-saltadora                não
# 47                                           Rã-grilo                não
# 48                                     Apito-do-brejo                não
# 49                             Apito-do-brejo-pequeno                NaN
# 50                                 Sapo-verrruga-liso                não
# 51         Sapo-verruguinha; Sapo-caminho-de-Salvator                não
# 52                                       Sapo verruga                não
# 53                   Sapo-verruga-de-palpebra-redonda                sim
#
#    Endêmico (Cerrado)      Red List  \
# 0                 sim            NT
# 1                 não            LC
# 2                 sim  não avaliada
# 3                 sim            LC
# 4                 não            LC
# 5                 sim            LC
# 6                 sim            LC
# 7                 sim  não avaliada
# 8                 sim            LC
# 9                 sim            LC
# 10                não            LC
# 11                sim            LC
# 12                não            LC
# 13                sim            DD
# 14                sim            LC
# 15                sim            LC
# 16                sim            DD
# 17                não            LC
# 18                NaN           NaN
# 19                não            LC
# 20                sim            DD
# 21                não            LC
# 22                não            LC
# 23                não            LC
# 24                sim           NaN
# 25                não            LC
# 26                sim           NaN
# 27                sim            LC
# 28                sim  não avaliada
# 29                não            LC
# 30                sim            LC
# 31                sim  não avaliada
# 32                sim  não avaliada
# 33                sim            LC
# 34                não            LC
# 35                não            LC
# 36                não            LC
# 37                não            LC
# 38                sim            LC
# 39                sim            LC
# 40                sim            DD
# 41                não            LC
# 42                NaN           NaN
# 43                sim            LC
# 44                não            LC
# 45                não            LC
# 46                sim            LC
# 47                sim            LC
# 48                sim  não avaliada
# 49                NaN           NaN
# 50                sim            LC
# 51                sim            DD
# 52                sim            LC
# 53                sim  não avaliada
#
#    Habitat de vida (mata ou floresta/area aberta/pedras)*  \
# 0                                       floresta (Fh)
# 1                                       floresta (Fh)
# 2                 cerrado (Ce) e areas alteradas (Aa)
# 3   areas abertas (Of), Cerrado (Ce), floresta (Fh...
# 4   areas abertas (Of), Cerrado (Ce), floresta (Fh...
# 5                        floresta (Fh), cerrado, (Ce)
# 6                    areas abertas (Of), Cerrado (Ce)
# 7                                       floresta (Fh)
# 8    areas abertas (Of), Cerrado (Ce) e floresta (Fh)
# 9                    areas abertas (Of), Cerrado (Ce)
# 10  areas abertas (Of), Cerrado (Ce) e áreas alter...
# 11  areas abertas (Of), Cerrado (Ce) e áreas alter...
# 12  areas abertas (Of), Cerrado (Ce) e áreas alter...
# 13                       floresta (Fh) e Cerrado (Ce)
# 14                                    Floresta (Fh)
# 15                                    Floresta (Fh)
# 16                                    Floresta (Fh)
# 17  areas abertas (Of), Floresta (Fh)  e áreas alt...
# 18                                                NaN
# 19  areas abertas (Of), Cerrado (Ce), floresta (Fh...
# 20                   areas abertas (Of), Cerrado (Ce)
# 21                   areas abertas (Of), Cerrado (Ce)
# 22  areas abertas (Of), Cerrado (Ce), areas altera...
# 23  areas abertas (Of), Cerrado (Ce), floresta (Fh...
# 24                                 areas abertas (Of)
# 25  areas abertas (Of), Cerrado (Ce), floresta (Fh...
# 26    areas abertas (Of), Cerrado (Ce), floresta (Fh)
# 27                   areas abertas (Of), Cerrado (Ce)
# 28                   areas abertas (Of), Cerrado (Ce)
# 29               floresta (Fh) e áreas alteradas (Aa)
# 30                   areas abertas (Of), Cerrado (Ce)
# 31                  Areas abertas (Of), Cerrado(Ce)
# 32                  areas abertas (Of), Cerrado(Ce)
# 33                                 areas abertas (Of)
# 34  areas abertas (Of), Cerrado (Ce), floresta (Fh...
# 35  areas abertas (Of), Cerrado (Ce), floresta (Fh...
# 36    areas abertas (Of), Cerrado (Ce), floresta (Fh)
# 37                   areas abertas (of), cerrado (ce)
# 38                   areas abertas (of), cerrado (ce)
# 39                   areas abertas (of), cerrado (ce)
# 40                   areas abertas (of), cerrado (ce)
# 41  areas abertas (of); cerrado (ce); areas altera...
# 42                                                NaN
# 43                   áreas abertas (of); cerrado (ce)
# 44  areas abertas (of); cerrado (ce); areas altera...
# 45                   areas abertas (of); cerrado (ce)
# 46  areas abertas (of); cerrado (ce); habitats flo...
# 47  areas abertas (of); cerrado (ce); areas altera...
# 48  areas abertas (of); cerrado (ce); areas altera...
# 49                                                NaN
# 50                        Cerrado (Ce); floresta (Fh)
# 51                   áreas abertas (of); cerrado (ce)
# 52    areas abertas (Of), Cerrado (Ce), floresta (Fh)
# 53                   areas abertas (Of), Cerrado (Ce)
#
#               habitat_breeding  \
# 0               terrestre (Tr)
# 1                 Lêntico (Le)
# 2                 Lêntico (Le)
# 3   Lêntico (Le) e Lótico (Lo)
# 4   Lêntico (Le) e Lótico (Lo)
# 5               terrestre (Tr)
# 6               terrestre (Tr)
# 7                  Lótico (Lo)
# 8                  Lótico (Lo)
# 9                 Lêntico (Le)
# 10                Lêntico (Le)
# 11                Lêntico (Le)
# 12                Lêntico (Le)
# 13                 Lótico (Lo)
# 14                 Lótico (Lo)
# 15                 Lótico (Lo)
# 16                 Lótico (Lo)
# 17                Lêntico (Le)
# 18                         NaN
# 19                Lêntico (Le)
# 20                 Lótico (Lo)
# 21                Lêntico (Le)
# 22                Lêntico (Le)
# 23                Lêntico (Le)
# 24                Lêntico (Le)
# 25                Lêntico (Le)
# 26                 Lótico (Lo)
# 27                Lêntico (Le)
# 28                         NaN
# 29                Lêntico (Le)
# 30                Lêntico (Le)
# 31                Lêntico (Le)
# 32                Lêntico (Le)
# 33                Lêntico (Le)
# 34                Lêntico (Le)
# 35                Lêntico (Le)
# 36                Lêntico (Le)
# 37                Lêntico (Le)
# 38                Lêntico (Le)
# 39                Lêntico (Le)
# 40                 Lótico (Lo)
# 41                Lêntico (Le)
# 42                         NaN
# 43                         NaN
# 44                Lêntico (Le)
# 45                Lêntico (Le)
# 46                Lêntico (Le)
# 47                Lêntico (Le)
# 48                Lêntico (Le)
# 49                         NaN
# 50                Lêntico (Le)
# 51                         NaN
# 52                 Lótico (Lo)
# 53                 Lótico (Lo)
#
#                     Poleiro (tipical calling perch)*   \
# 0                                      Terrestre (Te)
# 1                                      Terrestre (Te)
# 2                                      Terrestre (Te)
# 3                                      Terrestre (Te)
# 4                                      Terrestre (Te)
# 5                                      Terrestre (Te)
# 6                                      Terrestre (Te)
# 7          Arbustos baixos (Hb) e arbustos altos (Lb)
# 8               Terrestre (Te) e arbustos baixos (Lb)
# 9                                          Grama (Gr)
# 10                  arbustos baixos (Lb) e Grama (Gr)
# 11                                         Grama (Gr)
# 12  arbustos baixos (Lb), arbustos altos (Hb) e Gr...
# 13          arbustos baixos (Lb), arbustos altos (Hb)
# 14          arbustos baixos (Lb), arbustos altos (Hb)
# 15          arbustos baixos (Lb), arbustos altos (Hb)
# 16          arbustos baixos (Lb), arbustos altos (Hb)
# 17                               arbustos baixos (Lb)
# 18                                                NaN
# 19  arbustos baixos (Lb), arbustos altos (Hb), Ter...
# 20  arbustos baixos (Lb), Terrestre (Te) e Grama (Gr)
# 21                                         Grama (Gr)
# 22                  Grama (Gr) e arbustos baixos (Lb)
# 23  arbustos baixos (Lb), arbustos altos (Hb), Gra...
# 24                        Grama (Gr) e Terrestre (Tr)
# 25  arbustos baixos (Lb), arbustos altos (Hb), Gra...
# 26              arbustos baixos (Lb) e Terrestre (Tr)
# 27                                         Grama (Gr)
# 28                                     Terrestre (Te)
# 29          arbustos baixos (Lb), arbustos altos (Hb)
# 30                                     Terrestre (Te)
# 31                                     Terrestre (Te)
# 32                                     Terrestre (Te)
# 33                                     Terrestre (Te)
# 34                                     Terrestre (Te)
# 35                                     Terrestre (Te)
# 36                                     Terrestre (Te)
# 37                                     Terrestre (Te)
# 38                                     Terrestre (Te)
# 39                                     Terrestre (Te)
# 40                                     Terrestre (Te)
# 41                                     Terrestre (Te)
# 42                                                NaN
# 43                                     Terrestre (Te)
# 44                                     Terrestre (Te)
# 45                                     Terrestre (Te)
# 46                                     Terrestre (Te)
# 47                                     Terrestre (Te)
# 48                                     Terrestre (Te)
# 49                                                NaN
# 50                                     Terrestre (Te)
# 51                                     Terrestre (Te)
# 52                                     Terrestre (Te)
# 53                                     Terrestre (Te)
#
#    Atividade (noturno/diurno) Tamanho real (mm) - fêmea  \
# 0                      diurno                   16.8-17
# 1                     noturno                       180
# 2                     noturno                     49-73
# 3                     noturno                       NaN
# 4                     noturno                   150-200
# 5                      diurno                       NaN
# 6                      diurno                     20-24
# 7                     noturno                      33.7
# 8                     noturno                 60.2-61.6
# 9                     noturno                       NaN
# 10                    noturno                     23-26
# 11                    noturno                     21-25
# 12                    noturno                       NaN
# 13                    noturno                       NaN
# 14                    noturno                       NaN
# 15                    noturno                       NaN
# 16                    noturno                       NaN
# 17                    noturno                       NaN
# 18                        NaN                       NaN
# 19                    noturno                        44
# 20                    noturno                       NaN
# 21                    noturno                       NaN
# 22                    noturno                       NaN
# 23                    noturno                       NaN
# 24                    noturno                   28-34.5
# 25                    noturno                       NaN
# 26                    noturno                       NaN
# 27                    noturno                       NaN
# 28                    noturno                 26.7-31.7
# 29           noturno e diurno                    93-114
# 30                    noturno                       NaN
# 31                    noturno                       NaN
# 32          noturno e diurno                        NaN
# 33                    noturno                       NaN
# 34                    noturno                       NaN
# 35                    noturno                       NaN
# 36                    noturno                 40.6-46.6
# 37                    noturno            46,9 a 70,0 mm
# 38                    noturno                   54.3 mm
# 39                    noturno                  70–90 mm
# 40                    noturno              35.8–41.4 mm
# 41                    noturno                        80
# 42                        NaN                       NaN
# 43                    noturno             29,06-39,4 mm
# 44                    noturno                        30
# 45                    noturno                       NaN
# 46          noturno e diurno                        NaN
# 47                    noturno                   20.6 mm
# 48                    noturno                      30mm
# 49                        NaN                       NaN
# 50                    noturno                  45–70 mm
# 51                    noturno               26.8-27.8mm
# 52          noturno e diurno                        NaN
# 53          noturno e diurno                        NaN
#
#    Tamanho real (mm) - macho       Meses de Ocorrência    detectability  \
# 0                    16.8-17                       NaN       Muito raro
# 1                         68                       NaN             Raro
# 2                      40-71                       NaN             Raro
# 3                        NaN                  ano todo        Frequente
# 4                        NaN                  ano todo  Muito frequente
# 5                  23.1-29.4                     chuva        Frequente
# 6                        NaN                  ano todo             Raro
# 7                    30.7–36  Chuva (Dezembro a Março)             Raro
# 8                  51.9-65.3                     chuva        Frequente
# 9                        NaN                     chuva        Frequente
# 10                       NaN                  ano todo        Frequente
# 11                     18-23                     chuva  Muito frequente
# 12                       NaN                  ano todo  Muito frequente
# 13                       NaN                     chuva             Raro
# 14                       NaN                  ano todo        Frequente
# 15                      65.4                  ano todo  Muito frequente
# 16                       NaN                     chuva        Frequente
# 17                       NaN                  ano todo        Frequente
# 18                       NaN                       NaN              NaN
# 19                        37                  ano todo        Frequente
# 20                       NaN                     chuva             Raro
# 21                       NaN                     Chuva        Frequente
# 22                       NaN                  ano todo        Frequente
# 23                       NaN                  ano todo  Muito frequente
# 24                   25-35.6                     Chuva             Raro
# 25                       NaN                     chuva        Frequente
# 26                 13.5-22.2                     chuva             Raro
# 27                 28.4-30.8                  ano todo        Frequente
# 28                 21.9-27.7                     chuva             Raro
# 29                    70-101                  ano todo        Frequente
# 30                 18.6-20.5                     chuva             Raro
# 31                     19 mm                     chuva             Raro
# 32                 20.1-22.5                     chuva             Raro
# 33                       NaN                  Ano todo        Frequente
# 34                       NaN                  Ano todo  Muito frequente
# 35                       NaN                  Ano todo  Muito frequente
# 36                   40.4-45                     chuva        Frequente
# 37            50,8 a 58,4 mm                     chuva        Frequente
# 38                   51.0 mm                     chuva             Raro
# 39                  58–83 mm                     chuva             Raro
# 40              29.8–33.4 mm                     chuva             Raro
# 41                       120                  Ano todo  Muito frequente
# 42                       NaN                       NaN              NaN
# 43            30,25-38,55 mm                   set-jan  Muito frequente
# 44                        28                  Ano todo  Muito frequente
# 45                       NaN                  Ano todo  Muito frequente
# 46                       NaN                     chuva        Frequente
# 47                    17.4mm                     chuva        Frequente
# 48                       NaN                     chuva        Frequente
# 49                       NaN                       NaN              NaN
# 50                 50–60 mm                 seca-chuva        frequente
# 51               26.8-27.8mm                   Out-dez       frequente*
# 52              38.8-46.5 mm                  ano todo        Frequênte
# 53              30.4–39.3 mm                  Ano todo             Raro
#
#           Distribuição - SITE REUBER (espécies do DF)  \
# 0
# 1
# 2
# 3   Espécie com ampla distribuição associada ao bi...
# 4   Espécie com ampla distribuição podendo ser enc...
# 5   Espécie restrita ao bioma Cerrado, pode ser en...
# 6   Espécie com ampla distribuição no bioma Cerrad...
# 7   Sua distribuição é no estado do DF e no Goiás,...
# 8
# 9   Espécie associada ao bioma Cerrado. Ocorre nos...
# 10  Espécie amplamente distribuída na América do S...
# 11  Espécie de ampla distribuição no Brasil centra...
# 12  Espécie de ampla distribuição ocorrendo desde ...
# 13
# 14  Espécie de ampla distribuição no Brasil Centra...
# 15  Espécie endêmica do bioma Cerrado, ocorrendo n...
# 16
# 17  No Brasil está presente em praticamente todos ...
# 18                                                NaN
# 19  É encontrada nos estados de Rondônia, Tocantin...
# 20  Espécie associada às regiões de serras e chapa...
# 21  Espécie de ampla distribuição geográfica, ocor...
# 22  Espécie de ampla distribuição podendo ser enco...
# 23  Espécie de ampla distribuição ocorrendo desde ...
# 24  Espécie associada às serras e chapadas do esta...
# 25  Espécie ocorre no Brasil e Paraguai (Conchran,...
# 26  Espécie conhecida para o Goiás e Distrito Fede...
# 27  Espécie conhecida no estados de Minas Gerais, ...
# 28
# 29  Espécie de ampla distribuição. Ocorre desde o ...
# 30
# 31  Espécie conhecida para os estados do Goiás, re...
# 32  Espécie endêmica do bioma Cerrado. Conhecida p...
# 33  Ocorre nos estados da Bahia, Tocantins, Goiás,...
# 34  Está presente em quase todo o território brasi...
# 35  Distribuição está associada às regiões de form...
# 36  Espécie com ampla distribuição, podendo ser en...
# 37  Espécie de ampla distribuição, desde o leste d...
# 38  Espécie ocorre nos estados do Goiás, Minas Ger...
# 39  A espécie possui ampla distribuição geográfica...
# 40
# 41  A táxon possui ampla distribuição, podendo oco...
# 42                                                NaN
# 43  A distribuição geográfica da espécie é ampla e...
# 44  Espécie de ampla distribuição geográfica. Ocor...
# 45  Possivelmente a espécie do gênero com a mais a...
# 46  Espécie associada ao bioma Cerrado. Ocorre na ...
# 47  Espécie conhecida para região central do Brasi...
# 48  Espécie com ampla distribuição e pode ser enco...
# 49                                                NaN
# 50  Ocorre em regiões de altitudes acima de 800 me...
# 51  Espécie associada ao planalto central goiano, ...
# 52  Espécie conhecida para o estado do Goiás, Dist...
# 53
#
#                Ameaças - SITE REUBER (espécies do DF)
# 0
# 1
# 2
# 3   Desmatamentos e remoção de hábitats constituem...
# 4                               Espécie não ameaçada.
# 5   Desmatamento e remoção de hábitats constituem ...
# 6                 Desmatamentos e remoção de habitat.
# 7
# 8
# 9                                                 NaN
# 10                                Taxon não ameaçado.
# 11                                                NaN
# 12                                Taxon não ameaçado.
# 13                                                NaN
# 14                                                NaN
# 15  Exploração madeireira, construção de reservató...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  Expansão das fronteiras agropecuárias, constru...
# 21                              Espécie não ameaçada.
# 22                                                NaN
# 23                              Espécie não ameaçada.
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                              Espécie não ameaçada.
# 28
# 29                              Espécie não ameaçada.
# 30                                                NaN
# 31                                                NaN
# 32  Expansão das fronteiras agropecuárias, fragmen...
# 33                                                NaN
# 34  Exploração madeireira, construção de reservató...
# 35         Caça é uma possível ameaça para e espécie.
# 36                                                NaN
# 37  Espécie não ameaçada. Algumas das possíveis am...
# 38                                                NaN
# 39  Exploração madeireira, construção de reservató...
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                              Espécie não ameaçada.
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52  Expansão das fronteiras agropecuárias e a expl...
# 53                                                NaN

# %% [markdown]
# ### Species name, id and Authorship

# %%
df['scientificName'] = df['speciesName'].apply(lambda x: re.findall( '^\w+(?: cf.| aff.)? \w+\.?', str(x))[0])

# %%
df['scientificNameAuthorship'] = df[['speciesName','scientificName']].apply(lambda x: x[0][len(x[1]):], axis=1)
df['scientificNameAuthorship'] = df['scientificNameAuthorship'].apply(lambda x: re.findall( '[\w,\s\-&]+', str(x) )).apply(lambda x: ''.join(x).strip())

# %%
ids = df['scientificName'].str.replace('\s','-').str.replace('[.]','').str.lower()
df.insert(0, 'id', ids)

# %%
df.drop('speciesName', axis=1, inplace=True)

# %% [markdown]
# ### Family name and id

# %%
df['family'] = df['family'].apply(lambda x: x.capitalize())
df['family_id'] = df['family'].str.lower()

# %% [markdown]
# ### Vernacular name

# %%
def extractVernacularNames(string):
    names = re.split('/|;|,',string)
    names = [ n.strip().replace(' ','-').capitalize() for n in names ]
    if len(names)==1 and names[0]=='':
        return []
    else:
        return names

# %%
df['vernacularNames'] = df['vernacularNames'].apply(extractVernacularNames)

# %% [markdown]
# ### Red list

# %%
df['Red List'] = df['Red List'].str.lower()
df.loc[ df['Red List']=='não avaliada','Red List']='ne'

# %%
df = pd.get_dummies(data=df, prefix='redlist', columns=['Red List'])

# %% [markdown]
# ### Endemicidade

# %%
df['endemic_cerrado'] = df['Endêmico (Cerrado)'].apply(lambda x: 1 if x=='sim' else 0)
df['endemic_chapada'] = df['Endêmico (Chapada)'].apply(lambda x: 1 if x=='sim' else 0)
df.drop('Endêmico (Chapada)', axis=1, inplace=True)
df.drop('Endêmico (Cerrado)', axis=1, inplace=True)

# %%
# Helpers

getInsideParentheses = lambda x: [ str.lower(e) for e in re.findall( '\((.{0,5})\)', str(x) ) ]

# %% [markdown]
# ### Detectability

# %%
df['detectability'] = df['detectability']\
    .str.replace('[^\w]','')\
    .str.replace('ê','e')\
    .str.lower()

# %%
subst_dict = {
    'muitofrequente': 'ff',
    'frequente':'f',
    'raro': 'r',
    'muitoraro': 'rr'
}

df['detectability'] = df['detectability'].apply(lambda x: subst_dict[x] if x is not np.NaN else x)
df = pd.get_dummies(df, prefix='detectability',columns=['detectability'])

# %% [markdown]
# ### Poleiro

# %%
df['poleiro'] = df['Poleiro (tipical calling perch)* '].apply( getInsideParentheses )
df.drop('Poleiro (tipical calling perch)* ', axis=1, inplace=True)

# %%
poleiro_types = list(set( el for ls in df['poleiro'] for el in ls))

# %%
for tp in poleiro_types:
    df[f'tcp_{tp}'] = df['poleiro'].apply(lambda x: 1 if f'{tp}' in x else 0)

# %%
df.drop('poleiro', axis=1, inplace=True)

# %% [markdown]
# ### Habitat breeding

# %%
matches = df['habitat_breeding'].str.lower().str.extractall('\((\w+)\)')
hb_dummies = pd.get_dummies(matches, prefix="habitat_breeding").groupby(level=0).sum()

# %%
hb_dummies = hb_dummies.reindex(df.index).fillna(0).astype(int)

# %%
df = pd.concat([df,hb_dummies], axis=1)

# %%
df.drop('habitat_breeding',axis=1, inplace=True)

# %% [markdown]
# ### Habitat

# %%
df['habitat'] = df['Habitat de vida (mata ou floresta/area aberta/pedras)*'].apply( getInsideParentheses)
df.drop('Habitat de vida (mata ou floresta/area aberta/pedras)*', axis=1, inplace=True)

# %%
habitat_types = list(set( el for ls in df['habitat'] for el in ls ))

# %%
for tp in habitat_types:
    df[f'habitat_{tp}'] = df['habitat'].apply(lambda x: 1 if f'{tp}' in x else 0)

# %%
df.drop('habitat', axis=1, inplace=True)

# %% [markdown]
# ### Atividade

# %%
df['Atividade (noturno/diurno)'].value_counts()
# Out:
# noturno              43
# noturno e diurno      4
# diurno                3
# noturno e diurno      1
# Name: Atividade (noturno/diurno), dtype: int64

# %%
df['atividade_diu'] = df['Atividade (noturno/diurno)'].apply(lambda x: 1 if 'diurno' in str(x) else 0)
df['atividade_not'] = df['Atividade (noturno/diurno)'].apply(lambda x: 1 if 'noturno' in str(x) else 0)
df.drop('Atividade (noturno/diurno)', axis=1, inplace=True)

# %%
df['Ameaças - SITE REUBER (espécies do DF)'][5]
# Out:
# 'Desmatamento e remoção de hábitats constituem ameaças as populações locais.'

# %% [markdown]
# ### Tamanho

# %%
df['tamanho_femea'] = df['Tamanho real (mm) - fêmea'].apply(lambda x: re.findall( '([0-9\.]+)' , str(x).replace(',','.')))
df['tamanho_macho'] = df['Tamanho real (mm) - macho'].apply(lambda x: re.findall( '([0-9\.]+)' , str(x).replace(',','.')))

# %%
df['tamanho_femea_med'] = df['tamanho_femea'].apply( lambda l: sum([float(i) for i in l])/len(l) if len(l)>0 else None )
df['tamanho_macho_med'] = df['tamanho_macho'].apply( lambda l: sum([float(i) for i in l])/len(l) if len(l)>0 else None )

# %%
#df['tamanho_femea_min'] = df['tamanho_femea'].apply( lambda x: min([ float(i) for i in x]) if len(x) > 0 else None)
#df['tamanho_femea_max'] = df['tamanho_femea'].apply( lambda x: max([ float(i) for i in x]) if len(x) > 0 else None)
#df['tamanho_macho_min'] = df['tamanho_macho'].apply( lambda x: min([ float(i) for i in x]) if len(x) > 0 else None)
#df['tamanho_macho_max'] = df['tamanho_macho'].apply( lambda x: max([ float(i) for i in x]) if len(x) > 0 else None)

#df['tamanho_macho_max'].replace(np.NaN, df['tamanho_femea_max'], inplace=True)
#df['tamanho_macho_min'].replace(np.NaN, df['tamanho_femea_min'], inplace=True)
#df['tamanho_femea_max'].replace(np.NaN, df['tamanho_macho_max'], inplace=True)
#df['tamanho_femea_min'].replace(np.NaN, df['tamanho_femea_min'], inplace=True)

# %%
df.drop('tamanho_femea', axis=1, inplace=True)
df.drop('tamanho_macho', axis=1, inplace=True)
df.drop('Tamanho real (mm) - fêmea', axis=1, inplace=True)
df.drop('Tamanho real (mm) - macho', axis=1, inplace=True)

# %%
df['tamanho_macho_med'].replace(np.NaN, df['tamanho_femea_med'], inplace=True)
df['tamanho_femea_med'].replace(np.NaN, df['tamanho_macho_med'], inplace=True)
df['tamanho_med'] = df[['tamanho_macho_med','tamanho_femea_med']].mean(axis=1)

# %% [markdown]
# ### Meses de ocorrência

# %% [markdown]
# 1. Extract month ranges from strings

# %%
import unicodedata

normalize_str = lambda x: unicodedata.normalize('NFKD',x).encode('ascii', errors='ignore').decode('utf-8').lower().strip()
months=['janeiro','fevereiro','marco','abril','maio','junho','julho','agosto','setembro','outubro','novembro','dezembro',
        'jan','fev','mar','abr','mai','jun','jul','ago','set','out','nov','dez']

# %%
df['Meses de Ocorrência'] = df['Meses de Ocorrência'].apply(lambda x: normalize_str(x) if pd.notnull(x) else x)\
    .replace('chuva','out-mar')\
    .replace('ano todo', 'jan-dez')\
    .replace('seca-chuva','jan-dez')\
    .str.findall("("+"|".join(months)+")")\
    .apply(lambda x: [ i[:3] for i in x] if isinstance(x,list) else x)\
    .str.join(sep='-')\

# %%
def occurrence_months(m_start, m_end):
    d=['jan','fev','mar','abr','mai','jun','jul','ago','set','out','nov','dez']
    idx_mstart = d.index(m_start)
    idx_mend = d.index(m_end)
    
    if idx_mstart > idx_mend:
        return d[idx_mstart:]+d[:idx_mend+1]
    else:
        return d[idx_mstart:idx_mend+1]
    
    
def months_to_array(mths):
    d=['jan','fev','mar','abr','mai','jun','jul','ago','set','out','nov','dez']
    return [ 1 if i in mths else 0 for i in d ]

# %%
df['month_vec'] = df['Meses de Ocorrência'].str.split('-').apply(
    lambda x: months_to_array(occurrence_months(*x)) if isinstance(x,list) else [0 for i in range(12)]
)

# %% [markdown]
# ### Temporarily remove unused fields

# %%
df.drop('Distribuição - SITE REUBER (espécies do DF)', axis=1, inplace=True)
df.drop('Ameaças - SITE REUBER (espécies do DF)', axis=1, inplace=True)

# %% [markdown]
# ### Remove unwanted species

# %%
spp_to_remove = ['boana-sp','leptodactylus-aff-cunicularius','elachistocleis-sp']

# %%
df = df[ df['id'].apply(lambda x: x not in spp_to_remove) ]

# %% [markdown]
# ### Sort dataframe by Family and id

# %%
df = df.sort_values(by=['family','id'])

# %% [markdown]
# ### Write to json

# %%
species_data_path = '../_data/species.json'

d = df.to_dict(orient='records')

with open(species_data_path, 'w') as f:
    json.dump(d, f,indent=1, ensure_ascii=False)
