# %%
import pandas as pd
import numpy as np
import re
import json

# %%
pd.set_option('display.max_columns',50)

# %%
dataFile = './speciesdata.csv'

# %%
excludedCols = ['Responsável','Guia','Folder','Artigo','Família.1', 
                'Glossário','Fotos adultos','Fotos girinos',
                'Vídeos','Áudios', 'Diagnose','DOI' ]

df = pd.read_csv(dataFile, usecols=lambda x: x not in excludedCols)

# %%
# Drop every row after the one containing only null values
nullrow = df[df.apply(lambda x: all(x.isnull()), axis=1)].index[0]
df.drop(axis=1, index=range( nullrow,df.shape[0] ), inplace=True)

# %%
df.drop('Red List.1', axis=1, inplace=True)

# %%
df.rename( {'Espécie': 'speciesName', 
            'Família': 'family',
            'Postura dos ovos (habitat breeding)*': 'habitat_breeding',
            'Chances de encontros (muito raro/raro/frequente/muito frequente)': 'detectability',
            'Nome Comum': 'vernacularNames'}, axis=1, inplace=True)

# %%
df.replace('^-$', '', inplace=True, regex=True)

# %%
df
# Out:
#                        family  \
# 0                AROMOBATIDAE
# 1                   BUFONIDAE
# 2                   BUFONIDAE
# 3                   BUFONIDAE
# 4                   BUFONIDAE
# 5                   BUFONIDAE
# 6   CRAUGASTORIDAE *confirmar
# 7               DENDROBATIDAE
# 8                     HYLIDAE
# 9                     HYLIDAE
# 10                    HYLIDAE
# 11                    HYLIDAE
# 12                    HYLIDAE
# 13                    HYLIDAE
# 14                    HYLIDAE
# 15                    HYLIDAE
# 16                    HYLIDAE
# 17                    HYLIDAE
# 18                    HYLIDAE
# 19                    HYLIDAE
# 20                    HYLIDAE
# 21                    HYLIDAE
# 22                    HYLIDAE
# 23                    HYLIDAE
# 24                    HYLIDAE
# 25                    HYLIDAE
# 26                    HYLIDAE
# 27                    HYLIDAE
# 28                    HYLIDAE
# 29                    HYLIDAE
# ..                        ...
# 33                    HYLIDAE
# 34                    HYLIDAE
# 35            LEPTODACTYLIDAE
# 36            LEPTODACTYLIDAE
# 37            LEPTODACTYLIDAE
# 38            LEPTODACTYLIDAE
# 39            LEPTODACTYLIDAE
# 40            LEPTODACTYLIDAE
# 41            LEPTODACTYLIDAE
# 42            LEPTODACTYLIDAE
# 43            LEPTODACTYLIDAE
# 44            LEPTODACTYLIDAE
# 45            LEPTODACTYLIDAE
# 46            LEPTODACTYLIDAE
# 47            LEPTODACTYLIDAE
# 48            LEPTODACTYLIDAE
# 49            LEPTODACTYLIDAE
# 50            LEPTODACTYLIDAE
# 51            LEPTODACTYLIDAE
# 52            LEPTODACTYLIDAE
# 53            LEPTODACTYLIDAE
# 54            LEPTODACTYLIDAE
# 55            LEPTODACTYLIDAE
# 56            LEPTODACTYLIDAE
# 57               MICROHYLIDAE
# 58               MICROHYLIDAE
# 59            ODONTOPHRYNIDAE
# 60            ODONTOPHRYNIDAE
# 61            ODONTOPHRYNIDAE
# 62            ODONTOPHRYNIDAE
#
#                                           speciesName  \
# 0                 Allobates goianus (Bokermann, 1975)
# 1                   Rhaebo guttatus (Schneider, 1799)
# 2           Rhinella mirandaribeiroi (Gallardo, 1965)
# 3                   Rhinella ocellata (Günther, 1858)
# 4                     Rhinella rubescens (Lutz, 1925)
# 5                      Rhinella diptycha (Cope, 1862)
# 6        Barycholos ternetzi (Miranda- Ribeiro, 1937)
# 7                    Ameerega flavopicta (Lutz, 1925)
# 8   Aplastodiscus lutzorum Berneck, Giaretta, Bran...
# 9   Bokermannohyla pseudopseudis (Miranda-Ribeiro,...
# 10      Dendropsophus jimi (Napoli & Caramashi, 1999)
# 11               Dendropsophus minutus (Peters, 1872)
# 12              Dendropsophus nanus (Boulenger, 1889)
# 13  Dendropsophus rubicundulus (Reinhardt & Lutken...
# 14               Boana crepitans (Wied-Neuwied, 1824)
# 15                    Boana albopunctata (Spix, 1824)
# 16              Boana ericae (Caramashi & Cruz, 2000)
# 17                          Boana goiana (Lutz, 1968)
# 18                    Boana lundii (Burmeister, 1856)
# 19         Boana phaeopleura (Caramashi & Cruz, 2000)
# 20                          Boana raniceps Cope, 1862
# 21                                          Boana sp.
# 22          Pithecopus hypochondrialis (Daudin, 1800)
# 23                 Pithecopus oreades (Brandão, 2002)
# 24                    Pithecopus azureus (Cope, 1862)
# 25                    Pseudis bolbodactyla Lutz, 1925
# 26                  Scinax squalirostris (Lutz, 1925)
# 27                  Scinax fuscomarginatus Lutz, 1925
# 28                    Scinax fuscovarius (Lutz, 1925)
# 29     Scinax rogerioi Pugliese, Baêta & Pombal, 2009
# ..                                                ...
# 33  Scinax rupestris Araujo-Vieira, Brandão & Fari...
# 34          Trachycephalus typhonius (Linnaeus, 1758)
# 35         Adenomera cotuba Carvalho & Giaretta, 2013
# 36       Adenomera juikitam Carvalho & Giaretta, 2013
# 37           Adenomera saci Carvalho & Giaretta, 2013
# 38   Leptodactylus furnarius Sazima & Bokermann, 1978
# 39             Leptodactylus fuscus (Schneider, 1799)
# 40           Leptodactylus labyrinthicus (Spix, 1824)
# 41               Leptodactylus mystaceus (Spix, 1824)
# 42        Leptodactylus mystacinus (Burmeister, 1861)
# 43     Leptodactylus sertanejo Giaretta & Costa, 2007
# 44               Leptodactylus syphax Bokermann, 1969
# 45      Leptodactylus tapiti Sazima & Bokermann, 1978
# 46              Leptodactylus latrans (Steffen, 1815)
# 47  Leptodactylus aff. cunicularius Sazima & Boker...
# 48                 Leptodactylus chaquensis Cei, 1950
# 49             Leptodactylus podicipinus (Cope, 1862)
# 50  Physalaemus marmoratus (Reinhardt and Lutken, ...
# 51              Physalaemus centralis Bokermann, 1926
# 52                Physalaemus cuvieri Fitzinger, 1826
# 53           Pseudopaludicola mystacalis (Cope, 1887)
# 54              Pseudopaludicola saltica (Cope, 1887)
# 55    Pseudopaludicola ternetzi Miranda-Ribeiro, 1937
# 56          Pseudopaludicola giarettai Carvalho, 2012
# 57     Elachistocleis cesarii (Miranda-Ribeiro, 1920)
# 58                                 Elachistocleis sp.
# 59   Odontophrynus cultripes Reinhardt & Lutken, 1862
# 60            Odontophrynus salvatori Caramashi, 1996
# 61      Proceratophrys goyana (Miranda-Ribeiro, 1937)
# 62  Proceratophrys rotundipalpebra Martins & Giare...
#
#                                       vernacularNames Endêmico (Chapada)  \
# 0                                                                    não
# 1                                     Cururu de couro                não
# 2                                              Cururu                não
# 3                                              Cururu                não
# 4                                     Cururu-vermelho                não
# 5                                         Sapo cururu                não
# 6                                    Rãzinha da chuva                não
# 7                                         Sapo flecha                não
# 8                              Perereca-verde-da-mata                não
# 9                                      Falsa perereca                não
# 10                              Pererequinha do Brejo                não
# 11                                 pererequinha-miúda                não
# 12                                                NaN                NaN
# 13                            Perereca de Lagoa Santa                não
# 14                                                NaN                NaN
# 15                        Perereca de Pintas Amarelas                não
# 16                                Perereca-Chapadeira                sim
# 17                                 Perereca de Pijama                não
# 18                                     Perereca usina                não
# 19                         Perereca de Listras Marrom                sim
# 20              Perereca-do-Chaco; Perereca Chaquenha                não
# 21                                           perereca                NaN
# 22                                    Perereca-macaco                não
# 23                               Perereca do planalto                não
# 24                                                NaN                NaN
# 25                                                NaN                NaN
# 26                                  Perereca nariguda                não
# 27                              Pererequinha do brejo                não
# 28                    Perereca de banheiro; Rapa-cuia                não
# 29                                           Perereca                não
# ..                                                ...                ...
# 33                            Pererequinha-das-rochas                sim
# 34                                   Perereca babenta                não
# 35                                     Rãzinha-sumida                não
# 36                                  Rãzinha-verrucosa                sim
# 37                                            Rã saci                não
# 38                                   Rãzinha-cavadora                não
# 39                          Rã assobiadora/biscateira                não
# 40                                         Rã pimenta                não
# 41                                   Rã-bigode-branco                não
# 42  Rã-de-bigode (sugerido), Rã-assobiadora (Maffe...                não
# 43                                       Rã-do-sertão                não
# 44                                      Rã das pedras                não
# 45                                  Rãzinha-cavadeira                sim
# 46                                        Rã-manteiga                não
# 47                                   Rãzinha-forneira                NaN
# 48                                                NaN                NaN
# 49                                                NaN                NaN
# 50                                                NaN                NaN
# 51                   Rã fantasma; rã gatinho; rã ingá                não
# 52                       Rã cachorro; Foi-gol-não-foi                não
# 53                                      Rãzinha-grilo                não
# 54                                  Rãzinha-saltadora                não
# 55                                           Rã-grilo                não
# 56                                                NaN                NaN
# 57                                     Apito-do-brejo                não
# 58                             Apito-do-brejo-pequeno                NaN
# 59                                  Sapo-verruga-liso                não
# 60         Sapo-verruguinha; Sapo-caminho-de-Salvator                não
# 61                                       Sapo verruga                não
# 62                   Sapo-verruga-de-palpebra-redonda                sim
#
#    Endêmico (Cerrado)      Red List Diagnose escrita  \
# 0                 sim            DD               ok
# 1                 não            LC               ok
# 2                 sim  não avaliada               ok
# 3                 não            LC              NaN
# 4                 sim            LC               ok
# 5                 não            LC               ok
# 6                 sim            LC               ok
# 7                 sim            LC               ok
# 8                 sim  não avaliada               ok
# 9                 sim            LC               ok
# 10                sim            LC               ok
# 11                não            LC               ok
# 12                NaN           NaN              NaN
# 13                sim            LC               ok
# 14                NaN           NaN              NaN
# 15                não            LC               ok
# 16                sim            DD               ok
# 17                sim            LC               ok
# 18                sim            LC               ok
# 19                sim            DD               ok
# 20                não            LC               ok
# 21                NaN           NaN              NaN
# 22                não            LC               ok
# 23                sim            DD               ok
# 24                NaN           NaN              NaN
# 25                NaN           NaN              NaN
# 26                não            LC               ok
# 27                não            LC               ok
# 28                não            LC               ok
# 29                sim           NaN               ok
# ..                ...           ...              ...
# 33                sim  não avaliada               ok
# 34                não            LC               ok
# 35                sim            LC               ok
# 36                sim  não avaliada               ok
# 37                sim  não avaliada               ok
# 38                sim            LC               ok
# 39                não            LC               ok
# 40                não            LC               ok
# 41                não            LC               ok
# 42                não            LC               ok
# 43                sim            LC               ok
# 44                sim            LC               ok
# 45                sim            DD               ok
# 46                não            LC               ok
# 47                NaN           NaN              NaN
# 48                NaN           NaN              NaN
# 49                NaN           NaN              NaN
# 50                NaN           NaN              NaN
# 51                sim            LC               ok
# 52                não            LC               ok
# 53                não            LC               ok
# 54                sim            LC               ok
# 55                sim            LC               ok
# 56                NaN           NaN              NaN
# 57                sim  não avaliada               ok
# 58                NaN           NaN              NaN
# 59                sim            LC               ok
# 60                sim            DD               ok
# 61                sim            LC               ok
# 62                sim  não avaliada               ok
#
#    Habitat de vida (mata ou floresta/area aberta/pedras)*  \
# 0      Floresta: mata de galeria com ambiente rochoso
# 1                          Mata de galeria e cerradão
# 2                 cerrado (Ce) e areas alteradas (Aa)
# 3    cerrado (Ce) e areas alteradas (Aa), mata ciliar
# 4   areas abertas (Of), Cerrado (Ce), floresta (Fh...
# 5   areas abertas (Of), Cerrado (Ce), floresta (Fh...
# 6                        floresta (Fh), cerrado, (Ce)
# 7                    areas abertas (Of), Cerrado (Ce)
# 8                                       floresta (Fh)
# 9    areas abertas (Of), Cerrado (Ce) e floresta (Fh)
# 10                   areas abertas (Of), Cerrado (Ce)
# 11  areas abertas (Of), Cerrado (Ce) e áreas alter...
# 12                                                NaN
# 13  areas abertas (Of), Cerrado (Ce) e áreas alter...
# 14                                                NaN
# 15  areas abertas (Of), Cerrado (Ce) e áreas alter...
# 16                       floresta (Fh) e Cerrado (Ce)
# 17                                    Floresta (Fh)
# 18                                    Floresta (Fh)
# 19                                    Floresta (Fh)
# 20  areas abertas (Of), Floresta (Fh)  e áreas alt...
# 21                                                NaN
# 22  areas abertas (Of), Cerrado (Ce), floresta (Fh...
# 23                   areas abertas (Of), Cerrado (Ce)
# 24                                                NaN
# 25                                                NaN
# 26                   areas abertas (Of), Cerrado (Ce)
# 27  areas abertas (Of), Cerrado (Ce), areas altera...
# 28  areas abertas (Of), Cerrado (Ce), floresta (Fh...
# 29                                 areas abertas (Of)
# ..                                                ...
# 33                   areas abertas (Of), Cerrado (Ce)
# 34               floresta (Fh) e áreas alteradas (Aa)
# 35                   areas abertas (Of), Cerrado (Ce)
# 36                  Areas abertas (Of), Cerrado(Ce)
# 37                  areas abertas (Of), Cerrado(Ce)
# 38                                 areas abertas (Of)
# 39  areas abertas (Of), Cerrado (Ce), floresta (Fh...
# 40  areas abertas (Of), Cerrado (Ce), floresta (Fh...
# 41    areas abertas (Of), Cerrado (Ce), floresta (Fh)
# 42                   areas abertas (of), cerrado (ce)
# 43                   areas abertas (of), cerrado (ce)
# 44                   areas abertas (of), cerrado (ce)
# 45                   areas abertas (of), cerrado (ce)
# 46  areas abertas (of); cerrado (ce); areas altera...
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                   áreas abertas (of); cerrado (ce)
# 52  areas abertas (of); cerrado (ce); areas altera...
# 53                   areas abertas (of); cerrado (ce)
# 54  areas abertas (of); cerrado (ce); habitats flo...
# 55  areas abertas (of); cerrado (ce); areas altera...
# 56                                                NaN
# 57  areas abertas (of); cerrado (ce); areas altera...
# 58                                                NaN
# 59                        Cerrado (Ce); floresta (Fh)
# 60                   áreas abertas (of); cerrado (ce)
# 61    areas abertas (Of), Cerrado (Ce), floresta (Fh)
# 62                   areas abertas (Of), Cerrado (Ce)
#
#    Categorias fitofisionomias (guia)    Altitude            habitat_breeding  \
# 0                                 FG         NaN              terrestre (Tr)
# 1                             FG, CE         NaN                Lêntico (Le)
# 2                            CSS, AA         NaN                Lêntico (Le)
# 3                        FC, CSS, AA   200-1500m              terrestre (Tr)
# 4          FC, FG, CE, CSS, C, V, AA  430-1400 m  Lêntico (Le) e Lótico (Lo)
# 5          FC, FG, CE, CSS, C, V, AA         NaN  Lêntico (Le) e Lótico (Lo)
# 6                     FC, FG, CE,CSS         NaN              terrestre (Tr)
# 7                           SCR, CCR         NaN              terrestre (Tr)
# 8                             FC, FG         NaN                 Lótico (Lo)
# 9                         CR, FG, FC         NaN                 Lótico (Lo)
# 10                            C, CSS         NaN                Lêntico (Le)
# 11                        C, CSS, AA         NaN                Lêntico (Le)
# 12                               NaN         NaN                         NaN
# 13                        C, CSS, AA         NaN                Lêntico (Le)
# 14                               NaN         NaN                         NaN
# 15                        C, CSS, AA         NaN                Lêntico (Le)
# 16                       FC, FG, CSS         NaN                 Lótico (Lo)
# 17                            FC, FG         NaN                 Lótico (Lo)
# 18                         FC, FG, C         NaN                 Lótico (Lo)
# 19                            FC, FG         NaN                 Lótico (Lo)
# 20                     C, FC, FG, AA         NaN                Lêntico (Le)
# 21                               NaN         NaN                         NaN
# 22                C, CSS, FC, FG, AA         NaN                Lêntico (Le)
# 23                            C, CSS         NaN                 Lótico (Lo)
# 24                               NaN         NaN                         NaN
# 25                               NaN         NaN                         NaN
# 26                            C, CSS         NaN                Lêntico (Le)
# 27                        C, CSS, AA         NaN                Lêntico (Le)
# 28                C, CSS, FC, FG, AA         NaN                Lêntico (Le)
# 29                                 C       >900m                Lêntico (Le)
# ..                               ...         ...                         ...
# 33                        C, CSS, CR       1200m                         NaN
# 34                        FC, FG, AA         NaN                Lêntico (Le)
# 35                            C, CSS         NaN                Lêntico (Le)
# 36                            C, CSS         NaN                Lêntico (Le)
# 37                            C, CSS         NaN                Lêntico (Le)
# 38                                 C         NaN                Lêntico (Le)
# 39             C, CSS, AA, FC, FG, V         NaN                Lêntico (Le)
# 40             C, CSS, AA, FC, FG, V         NaN                Lêntico (Le)
# 41                            C, CSS         NaN                Lêntico (Le)
# 42                            C, CSS         NaN                Lêntico (Le)
# 43                            C, CSS         NaN                Lêntico (Le)
# 44                        C, CSS, AA         NaN                Lêntico (Le)
# 45                            C, CSS       1300m                 Lótico (Lo)
# 46             C, CSS, AA, FC, FG, V         NaN                Lêntico (Le)
# 47                               NaN  1110-1500m                         NaN
# 48                               NaN         NaN                         NaN
# 49                               NaN         NaN                         NaN
# 50                               NaN         NaN                         NaN
# 51                          CSS,C, V         NaN                         NaN
# 52             C, CSS, AA, FC, FG, V         NaN                Lêntico (Le)
# 53                        C, CE, CSS         NaN                Lêntico (Le)
# 54                    C, CSS, FC, FG         NaN                Lêntico (Le)
# 55                        C, CSS, AA         NaN                Lêntico (Le)
# 56                               NaN         NaN                         NaN
# 57                        C, CSS, AA         NaN                Lêntico (Le)
# 58                               NaN         NaN                         NaN
# 59                        CE, CSS, C         NaN                Lêntico (Le)
# 60                        CE, CSS, C         NaN                         NaN
# 61                        CE, CSS, C         NaN                 Lótico (Lo)
# 62                        CE, CSS, C         NaN                 Lótico (Lo)
#
#                     Poleiro (tipical calling perch)*   \
# 0                                      Terrestre (Te)
# 1                                      Terrestre (Te)
# 2                                      Terrestre (Te)
# 3                                      Terrestre (Te)
# 4                                      Terrestre (Te)
# 5                                      Terrestre (Te)
# 6                                      Terrestre (Te)
# 7                                      Terrestre (Te)
# 8          Arbustos baixos (Hb) e arbustos altos (Lb)
# 9               Terrestre (Te) e arbustos baixos (Lb)
# 10                                         Grama (Gr)
# 11                  arbustos baixos (Lb) e Grama (Gr)
# 12                                                NaN
# 13                                         Grama (Gr)
# 14                                                NaN
# 15  arbustos baixos (Lb), arbustos altos (Hb) e Gr...
# 16          arbustos baixos (Lb), arbustos altos (Hb)
# 17          arbustos baixos (Lb), arbustos altos (Hb)
# 18          arbustos baixos (Lb), arbustos altos (Hb)
# 19          arbustos baixos (Lb), arbustos altos (Hb)
# 20                               arbustos baixos (Lb)
# 21                                                NaN
# 22  arbustos baixos (Lb), arbustos altos (Hb), Ter...
# 23  arbustos baixos (Lb), Terrestre (Te) e Grama (Gr)
# 24                                                NaN
# 25                                                NaN
# 26                                         Grama (Gr)
# 27                  Grama (Gr) e arbustos baixos (Lb)
# 28  arbustos baixos (Lb), arbustos altos (Hb), Gra...
# 29                        Grama (Gr) e Terrestre (Tr)
# ..                                                ...
# 33                                     Terrestre (Te)
# 34          arbustos baixos (Lb), arbustos altos (Hb)
# 35                                     Terrestre (Te)
# 36                                     Terrestre (Te)
# 37                                     Terrestre (Te)
# 38                                     Terrestre (Te)
# 39                                     Terrestre (Te)
# 40                                     Terrestre (Te)
# 41                                     Terrestre (Te)
# 42                                     Terrestre (Te)
# 43                                     Terrestre (Te)
# 44                                     Terrestre (Te)
# 45                                     Terrestre (Te)
# 46                                     Terrestre (Te)
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                     Terrestre (Te)
# 52                                     Terrestre (Te)
# 53                                     Terrestre (Te)
# 54                                     Terrestre (Te)
# 55                                     Terrestre (Te)
# 56                                                NaN
# 57                                     Terrestre (Te)
# 58                                                NaN
# 59                                     Terrestre (Te)
# 60                                     Terrestre (Te)
# 61                                     Terrestre (Te)
# 62                                     Terrestre (Te)
#
#    Atividade (noturno/diurno) Tamanho real (mm) - fêmea  \
# 0                      diurno                   16.8-17
# 1                     noturno                       180
# 2                     noturno                     49-73
# 3                     noturno                        44
# 4                     noturno                        90
# 5                     noturno                   150-200
# 6                      diurno                     23-30
# 7                      diurno                     20-24
# 8                     noturno                      33.7
# 9                     noturno                 60.2-61.6
# 10                    noturno                     23-26
# 11                    noturno                     18-23
# 12                        NaN                       NaN
# 13                    noturno                     21-25
# 14                        NaN                       NaN
# 15                    noturno                        50
# 16                    noturno                        30
# 17                    noturno                        32
# 18                    noturno                        65
# 19                    noturno                       NaN
# 20                    noturno                        45
# 21                        NaN                     30-45
# 22                    noturno                     30-45
# 23                    noturno                       NaN
# 24                        NaN                       NaN
# 25                        NaN                       NaN
# 26                    noturno                        25
# 27                    noturno                     15-27
# 28                    noturno                        41
# 29                    noturno                   28-34.5
# ..                        ...                       ...
# 33                    noturno                 26.7-31.7
# 34           noturno e diurno                    93-114
# 35                    noturno                 18.6-20.5
# 36                    noturno                        19
# 37          noturno e diurno                  20.1-22.5
# 38                    noturno                     57-72
# 39                    noturno                     32-54
# 40                    noturno                       155
# 41                    noturno                 40.6-46.6
# 42                    noturno              46,9 a 70,0
# 43                    noturno                      54.3
# 44                    noturno                    70–90
# 45                    noturno                35.8–41.4
# 46                    noturno                        80
# 47                        NaN                     40-45
# 48                        NaN                       NaN
# 49                        NaN                       NaN
# 50                        NaN                       NaN
# 51                    noturno               29,06-39,4
# 52                    noturno                        30
# 53                    noturno                     14-16
# 54          noturno e diurno                         16
# 55                    noturno                      20.6
# 56                        NaN                       NaN
# 57                    noturno                        30
# 58                        NaN                       NaN
# 59                    noturno                    45–70
# 60                    noturno                 26.8-27.8
# 61          noturno e diurno                 38.8-46.5
# 62          noturno e diurno                 30.4–39.3
#
#    Tamanho real (mm) - macho       Meses de Ocorrência    detectability  \
# 0                    16.8-17                     chuva       Muito raro
# 1                         68                       NaN             Raro
# 2                      40-71                       NaN             Raro
# 3                        NaN           chuva até março        Frequente
# 4                        NaN                  ano todo        Frequente
# 5                        NaN                  ano todo  Muito frequente
# 6                        NaN                     chuva        Frequente
# 7                        NaN                  ano todo             Raro
# 8                    30.7–36  Chuva (Dezembro a Março)             Raro
# 9                  51.9-65.3                     chuva        Frequente
# 10                       NaN                     chuva        Frequente
# 11                       NaN                  ano todo        Frequente
# 12                       NaN                       NaN              NaN
# 13                     18-23                     chuva  Muito frequente
# 14                       NaN                       NaN              NaN
# 15                       NaN                  ano todo  Muito frequente
# 16                       NaN                     chuva             Raro
# 17                       NaN                  ano todo        Frequente
# 18                       NaN                  ano todo  Muito frequente
# 19                       NaN                     chuva        Frequente
# 20                       NaN                  ano todo        Frequente
# 21                       NaN                       NaN              NaN
# 22                       NaN                  ano todo        Frequente
# 23                       NaN                     chuva             Raro
# 24                       NaN                       NaN              NaN
# 25                       NaN                       NaN              NaN
# 26                       NaN                     Chuva        Frequente
# 27                       NaN                  ano todo        Frequente
# 28                       NaN                  ano todo  Muito frequente
# 29                   25-35.6                     Chuva             Raro
# ..                       ...                       ...              ...
# 33                 21.9-27.7                     chuva             Raro
# 34                    70-101                  ano todo        Frequente
# 35                       NaN                     chuva             Raro
# 36                       NaN                     chuva             Raro
# 37                       NaN                     chuva             Raro
# 38                       NaN                  Ano todo        Frequente
# 39                       NaN                  Ano todo  Muito frequente
# 40                       NaN                  Ano todo  Muito frequente
# 41                   40.4-45                     chuva        Frequente
# 42              50,8 a 58,4                      chuva        Frequente
# 43                        51                     chuva             Raro
# 44                    58–83                      chuva             Raro
# 45                29.8–33.4                      chuva             Raro
# 46                       120                  Ano todo  Muito frequente
# 47                       NaN                       NaN              NaN
# 48                       NaN                       NaN              NaN
# 49                       NaN                       NaN              NaN
# 50                       NaN                       NaN              NaN
# 51              30,25-38,55                    set-jan  Muito frequente
# 52                        28                  Ano todo  Muito frequente
# 53                       NaN                  Ano todo  Muito frequente
# 54                       NaN                     chuva        Frequente
# 55                      17.4                     chuva        Frequente
# 56                       NaN                       NaN              NaN
# 57                       NaN                     chuva        Frequente
# 58                       NaN                       NaN              NaN
# 59                    50–60                 seca-chuva        frequente
# 60                 26.8-27.8                   Out-dez       frequente*
# 61                       NaN                  ano todo        Frequênte
# 62                       NaN                  Ano todo             Raro
#
#                       DOI artigo descrição espécie  \
# 0   http://dx.doi.org/10.13128/Acta_Herpetol-17491
# 1                                           só pdf
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                        10.11646/zootaxa.4442.1.9
# 6                                              NaN
# 7                                              NaN
# 8                                              NaN
# 9                                              NaN
# 10                                             NaN
# 11                                             NaN
# 12                                             NaN
# 13                                             NaN
# 14                                             NaN
# 15                                             NaN
# 16                                             NaN
# 17                                             NaN
# 18                                             NaN
# 19                                             NaN
# 20                                             NaN
# 21                                             NaN
# 22                                             NaN
# 23                                             NaN
# 24                                             NaN
# 25                                             NaN
# 26                                             NaN
# 27                                             NaN
# 28                                             NaN
# 29                                             NaN
# ..                                             ...
# 33                                             NaN
# 34                                             NaN
# 35                                             NaN
# 36                                             NaN
# 37                                             NaN
# 38                                             NaN
# 39                                             NaN
# 40                                             NaN
# 41                                             NaN
# 42                                             NaN
# 43                                             NaN
# 44                                             NaN
# 45                                             NaN
# 46                                             NaN
# 47                                             NaN
# 48                                             NaN
# 49                                             NaN
# 50                                             NaN
# 51                                             NaN
# 52                                             NaN
# 53                                             NaN
# 54                                             NaN
# 55                                             NaN
# 56                                             NaN
# 57                                             NaN
# 58                                             NaN
# 59                                             NaN
# 60                                             NaN
# 61                                             NaN
# 62                                             NaN
#
#           Distribuição - SITE REUBER (espécies do DF)  \
# 0
# 1
# 2
# 3   Tocantins, Para´, Mato Grosso, Minas Gerais, a...
# 4   Espécie com ampla distribuição associada ao bi...
# 5   Espécie com ampla distribuição podendo ser enc...
# 6   Espécie restrita ao bioma Cerrado, pode ser en...
# 7   Espécie com ampla distribuição no bioma Cerrad...
# 8   Sua distribuição é no estado do DF e no Goiás,...
# 9
# 10  Espécie associada ao bioma Cerrado. Ocorre nos...
# 11  Espécie amplamente distribuída na América do S...
# 12                                                NaN
# 13  Espécie de ampla distribuição no Brasil centra...
# 14                                                NaN
# 15  Espécie de ampla distribuição ocorrendo desde ...
# 16
# 17  Espécie de ampla distribuição no Brasil Centra...
# 18  Espécie endêmica do bioma Cerrado, ocorrendo n...
# 19
# 20  No Brasil está presente em praticamente todos ...
# 21                                                NaN
# 22  É encontrada nos estados de Rondônia, Tocantin...
# 23  Espécie associada às regiões de serras e chapa...
# 24                                                NaN
# 25                                                NaN
# 26  Espécie de ampla distribuição geográfica, ocor...
# 27  Espécie de ampla distribuição podendo ser enco...
# 28  Espécie de ampla distribuição ocorrendo desde ...
# 29  Espécie associada às serras e chapadas do esta...
# ..                                                ...
# 33
# 34  Espécie de ampla distribuição. Ocorre desde o ...
# 35
# 36  Espécie conhecida para os estados do Goiás, re...
# 37  Espécie endêmica do bioma Cerrado. Conhecida p...
# 38  Ocorre nos estados da Bahia, Tocantins, Goiás,...
# 39  Está presente em quase todo o território brasi...
# 40  Distribuição está associada às regiões de form...
# 41  Espécie com ampla distribuição, podendo ser en...
# 42  Espécie de ampla distribuição, desde o leste d...
# 43  Espécie ocorre nos estados do Goiás, Minas Ger...
# 44  A espécie possui ampla distribuição geográfica...
# 45
# 46  A táxon possui ampla distribuição, podendo oco...
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51  A distribuição geográfica da espécie é ampla e...
# 52  Espécie de ampla distribuição geográfica. Ocor...
# 53  Possivelmente a espécie do gênero com a mais a...
# 54  Espécie associada ao bioma Cerrado. Ocorre na ...
# 55  Espécie conhecida para região central do Brasi...
# 56                                                NaN
# 57  Espécie com ampla distribuição e pode ser enco...
# 58                                                NaN
# 59  Ocorre em regiões de altitudes acima de 800 me...
# 60  Espécie associada ao planalto central goiano, ...
# 61  Espécie conhecida para o estado do Goiás, Dist...
# 62
#
#                Ameaças - SITE REUBER (espécies do DF)
# 0
# 1
# 2
# 3
# 4   Desmatamentos e remoção de hábitats constituem...
# 5                               Espécie não ameaçada.
# 6   Desmatamento e remoção de hábitats constituem ...
# 7                 Desmatamentos e remoção de habitat.
# 8
# 9
# 10                                                NaN
# 11                                Taxon não ameaçado.
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                Taxon não ameaçado.
# 16                                                NaN
# 17                                                NaN
# 18  Exploração madeireira, construção de reservató...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23  Expansão das fronteiras agropecuárias, constru...
# 24                                                NaN
# 25                                                NaN
# 26                              Espécie não ameaçada.
# 27                                                NaN
# 28                              Espécie não ameaçada.
# 29                                                NaN
# ..                                                ...
# 33
# 34                              Espécie não ameaçada.
# 35                                                NaN
# 36                                                NaN
# 37  Expansão das fronteiras agropecuárias, fragmen...
# 38                                                NaN
# 39  Exploração madeireira, construção de reservató...
# 40         Caça é uma possível ameaça para e espécie.
# 41                                                NaN
# 42  Espécie não ameaçada. Algumas das possíveis am...
# 43                                                NaN
# 44  Exploração madeireira, construção de reservató...
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                              Espécie não ameaçada.
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61  Expansão das fronteiras agropecuárias e a expl...
# 62                                                NaN
#
# [63 rows x 20 columns]

# %% [markdown]
# ### Species name, id and Authorship

# %%
df['scientificName'] = df['speciesName'].apply(lambda x: re.findall( '^\w+(?: cf.| aff.)? \w+\.?', str(x))[0])

# %%
df['scientificNameAuthorship'] = df[['speciesName','scientificName']].apply(lambda x: x[0][len(x[1]):], axis=1)
df['scientificNameAuthorship'] = df['scientificNameAuthorship'].apply(lambda x: re.findall( '[\w,\s\-&]+', str(x) )).apply(lambda x: ''.join(x).strip())

# %%
ids = df['scientificName'].str.replace('\s','-').str.replace('[.]','').str.lower()
df.insert(0, 'id', ids)

# %%
df.drop('speciesName', axis=1, inplace=True)

# %% [markdown]
# ### Family name and id

# %%
df['family'] = df['family'].apply(lambda x: x.capitalize())
df['family_id'] = df['family'].str.lower()

# %% [markdown]
# ### Vernacular name

# %%
def extractVernacularNames(string):
    if pd.isna(string): string=''
    names = re.split('/|;|,',string)
    names = [ n.strip().replace(' ','-').capitalize() for n in names ]
    if len(names)==1 and names[0]=='':
        return []
    else:
        return names

# %%
df['vernacularNames'] = df['vernacularNames'].apply(extractVernacularNames)

# %% [markdown]
# ### Red list

# %%
df['Red List'] = df['Red List'].str.lower()
df.loc[ df['Red List']=='não avaliada','Red List']='ne'

# %%
df = pd.get_dummies(data=df, prefix='redlist', columns=['Red List'])

# %% [markdown]
# ### Endemicidade

# %%
df['endemic_cerrado'] = df['Endêmico (Cerrado)'].apply(lambda x: 1 if x=='sim' else 0)
df['endemic_chapada'] = df['Endêmico (Chapada)'].apply(lambda x: 1 if x=='sim' else 0)
df.drop('Endêmico (Chapada)', axis=1, inplace=True)
df.drop('Endêmico (Cerrado)', axis=1, inplace=True)

# %%
# Helpers

getInsideParentheses = lambda x: [ str.lower(e) for e in re.findall( '\((.{0,5})\)', str(x) ) ]

# %% [markdown]
# ### Detectability

# %%
df['detectability'] = df['detectability']\
    .str.replace('[^\w]','')\
    .str.replace('ê','e')\
    .str.lower()

# %%
subst_dict = {
    'muitofrequente': 'ff',
    'frequente':'f',
    'raro': 'r',
    'muitoraro': 'rr'
}

df['detectability'] = df['detectability'].apply(lambda x: subst_dict[x] if x is not np.NaN else x)
df = pd.get_dummies(df, prefix='detectability',columns=['detectability'])

# %% [markdown]
# ### Poleiro

# %%
df['poleiro'] = df['Poleiro (tipical calling perch)* '].apply( getInsideParentheses )
df.drop('Poleiro (tipical calling perch)* ', axis=1, inplace=True)

# %%
poleiro_types = list(set( el for ls in df['poleiro'] for el in ls))

# %%
for tp in poleiro_types:
    df[f'tcp_{tp}'] = df['poleiro'].apply(lambda x: 1 if f'{tp}' in x else 0)

# %%
df.drop('poleiro', axis=1, inplace=True)

# %% [markdown]
# ### Habitat breeding

# %%
matches = df['habitat_breeding'].str.lower().str.extractall('\((\w+)\)')
hb_dummies = pd.get_dummies(matches, prefix="habitat_breeding").groupby(level=0).sum()

# %%
hb_dummies = hb_dummies.reindex(df.index).fillna(0).astype(int)

# %%
df = pd.concat([df,hb_dummies], axis=1)

# %%
df.drop('habitat_breeding',axis=1, inplace=True)

# %% [markdown]
# ### Phytophysiognomies categoricals

# %%
df.rename({'Categorias fitofisionomias (guia)': 'phytos'}, axis=1, inplace=True)

# %%
replaces = {
} 
df['phytos'] = df['phytos'].str.lower().str.strip().str.split('\s*,\s*')\
    .apply(lambda x: [replaces.get(i,i) for i in x] if isinstance(x,list) else '')\
    .str.join(',')

# %%
df['phytos']
# Out:
# 0                      fg
# 1                   fg,ce
# 2                  css,aa
# 3               fc,css,aa
# 4     fc,fg,ce,css,c,v,aa
# 5     fc,fg,ce,css,c,v,aa
# 6            fc,fg,ce,css
# 7                 scr,ccr
# 8                   fc,fg
# 9                cr,fg,fc
# 10                  c,css
# 11               c,css,aa
# 12
# 13               c,css,aa
# 14
# 15               c,css,aa
# 16              fc,fg,css
# 17                  fc,fg
# 18                fc,fg,c
# 19                  fc,fg
# 20             c,fc,fg,aa
# 21
# 22         c,css,fc,fg,aa
# 23                  c,css
# 24
# 25
# 26                  c,css
# 27               c,css,aa
# 28         c,css,fc,fg,aa
# 29                      c
#              ...
# 33               c,css,cr
# 34               fc,fg,aa
# 35                  c,css
# 36                  c,css
# 37                  c,css
# 38                      c
# 39       c,css,aa,fc,fg,v
# 40       c,css,aa,fc,fg,v
# 41                  c,css
# 42                  c,css
# 43                  c,css
# 44               c,css,aa
# 45                  c,css
# 46       c,css,aa,fc,fg,v
# 47
# 48
# 49
# 50
# 51                css,c,v
# 52       c,css,aa,fc,fg,v
# 53               c,ce,css
# 54            c,css,fc,fg
# 55               c,css,aa
# 56
# 57               c,css,aa
# 58
# 59               ce,css,c
# 60               ce,css,c
# 61               ce,css,c
# 62               ce,css,c
# Name: phytos, Length: 63, dtype: object

# %% [markdown]
# ### Habitat

# %%
df['habitat'] = df['Habitat de vida (mata ou floresta/area aberta/pedras)*'].apply( getInsideParentheses)
df.drop('Habitat de vida (mata ou floresta/area aberta/pedras)*', axis=1, inplace=True)

# %%
habitat_types = list(set( el for ls in df['habitat'] for el in ls ))

# %%
for tp in habitat_types:
    df[f'habitat_{tp}'] = df['habitat'].apply(lambda x: 1 if f'{tp}' in x else 0)

# %%
df.drop('habitat', axis=1, inplace=True)

# %% [markdown]
# ### Atividade

# %%
df['Atividade (noturno/diurno)'].value_counts()
# Out:
# noturno              44
# noturno e diurno      4
# diurno                3
# noturno e diurno      1
# Name: Atividade (noturno/diurno), dtype: int64

# %%
df['atividade_diu'] = df['Atividade (noturno/diurno)'].apply(lambda x: 1 if 'diurno' in str(x) else 0)
df['atividade_not'] = df['Atividade (noturno/diurno)'].apply(lambda x: 1 if 'noturno' in str(x) else 0)
df.drop('Atividade (noturno/diurno)', axis=1, inplace=True)

# %%
df['Ameaças - SITE REUBER (espécies do DF)'][5]
# Out:
# 'Espécie não ameaçada.'

# %% [markdown]
# ### Tamanho

# %%
df['tamanho_femea'] = df['Tamanho real (mm) - fêmea'].apply(lambda x: re.findall( '([0-9\.]+)' , str(x).replace(',','.')))
df['tamanho_macho'] = df['Tamanho real (mm) - macho'].apply(lambda x: re.findall( '([0-9\.]+)' , str(x).replace(',','.')))

# %%
df['tamanho_femea_med'] = df['tamanho_femea'].apply( lambda l: sum([float(i) for i in l])/len(l) if len(l)>0 else None )
df['tamanho_macho_med'] = df['tamanho_macho'].apply( lambda l: sum([float(i) for i in l])/len(l) if len(l)>0 else None )

# %%
#df['tamanho_femea_min'] = df['tamanho_femea'].apply( lambda x: min([ float(i) for i in x]) if len(x) > 0 else None)
#df['tamanho_femea_max'] = df['tamanho_femea'].apply( lambda x: max([ float(i) for i in x]) if len(x) > 0 else None)
#df['tamanho_macho_min'] = df['tamanho_macho'].apply( lambda x: min([ float(i) for i in x]) if len(x) > 0 else None)
#df['tamanho_macho_max'] = df['tamanho_macho'].apply( lambda x: max([ float(i) for i in x]) if len(x) > 0 else None)

#df['tamanho_macho_max'].replace(np.NaN, df['tamanho_femea_max'], inplace=True)
#df['tamanho_macho_min'].replace(np.NaN, df['tamanho_femea_min'], inplace=True)
#df['tamanho_femea_max'].replace(np.NaN, df['tamanho_macho_max'], inplace=True)
#df['tamanho_femea_min'].replace(np.NaN, df['tamanho_femea_min'], inplace=True)

# %%
df.drop('tamanho_femea', axis=1, inplace=True)
df.drop('tamanho_macho', axis=1, inplace=True)
df.drop('Tamanho real (mm) - fêmea', axis=1, inplace=True)
df.drop('Tamanho real (mm) - macho', axis=1, inplace=True)

# %%
df['tamanho_macho_med'].replace(np.NaN, df['tamanho_femea_med'], inplace=True)
df['tamanho_femea_med'].replace(np.NaN, df['tamanho_macho_med'], inplace=True)
df['tamanho_med'] = df[['tamanho_macho_med','tamanho_femea_med']].mean(axis=1)

# %% [markdown]
# ### Meses de ocorrência

# %% [markdown]
# 1. Extract month ranges from strings

# %%
import unicodedata

normalize_str = lambda x: unicodedata.normalize('NFKD',x).encode('ascii', errors='ignore').decode('utf-8').lower().strip()
months=['janeiro','fevereiro','marco','abril','maio','junho','julho','agosto','setembro','outubro','novembro','dezembro',
        'jan','fev','mar','abr','mai','jun','jul','ago','set','out','nov','dez']

# %%
df['Meses de Ocorrência'] = df['Meses de Ocorrência'].apply(lambda x: normalize_str(x) if pd.notnull(x) else x)\
    .replace('chuva','out-mar')\
    .replace('ano todo', 'jan-dez')\
    .replace('seca-chuva','jan-dez')\
    .replace('chuva ate marco','out-mar')\
    .str.findall("("+"|".join(months)+")")\
    .apply(lambda x: [ i[:3] for i in x] if isinstance(x,list) else x)\
    .str.join(sep='-')\

# %%
def occurrence_months(m_start, m_end):
    d=['jan','fev','mar','abr','mai','jun','jul','ago','set','out','nov','dez']
    idx_mstart = d.index(m_start)
    idx_mend = d.index(m_end)
    
    if idx_mstart > idx_mend:
        return d[idx_mstart:]+d[:idx_mend+1]
    else:
        return d[idx_mstart:idx_mend+1]
    
    
def months_to_array(mths):
    d=['jan','fev','mar','abr','mai','jun','jul','ago','set','out','nov','dez']
    return [ 1 if i in mths else 0 for i in d ]

# %%
df['month_vec'] = df['Meses de Ocorrência'].str.split('-').apply(
    lambda x: months_to_array(occurrence_months(*x)) if isinstance(x,list) else [0 for i in range(12)]
)

# %% [markdown]
# ### Temporarily remove unused fields

# %%
df.drop('Distribuição - SITE REUBER (espécies do DF)', axis=1, inplace=True)
df.drop('Ameaças - SITE REUBER (espécies do DF)', axis=1, inplace=True)

# %% [markdown]
# ### Remove unwanted species

# %%
spp_to_remove = ['boana-sp','leptodactylus-aff-cunicularius','elachistocleis-sp']

# %%
df = df[ df['id'].apply(lambda x: x not in spp_to_remove) ]

# %% [markdown]
# ### Sort dataframe by Family and id

# %%
df = df.sort_values(by=['family','id'])

# %% [markdown]
# ### Write to json

# %%
species_data_path = '../_data/species.json'

d = df.to_dict(orient='records')

with open(species_data_path, 'w') as f:
    json.dump(d, f,indent=1, ensure_ascii=False)
